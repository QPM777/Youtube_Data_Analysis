# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import copy

# %%
file_path = 'D:\_raw_yt_metadata.jsonl'
chunk_size = 400000

chunks = []

for chunk in pd.read_json(file_path, lines=True, chunksize=chunk_size):
    chunks.append(chunk)
    break

df = pd.concat(chunks, ignore_index=True)

# %% [markdown]
# Before everything, let's remove videos with empty categories to preprocess our data

# %%
count_empty_categories = (df["categories"]=="").sum()
print(f"Number of empty lines : {count_empty_categories}")

df = df[df["categories"] != ""]
df
# Out:
# Number of empty lines : 3
#               categories                channel_id  \
# 0          Entertainment  UCzzzrOhp92PkGrIwGH3_EEg
# 1          Entertainment  UCzzzrOhp92PkGrIwGH3_EEg
# 2          Entertainment  UCzzzrOhp92PkGrIwGH3_EEg
# 3          Entertainment  UCzzzrOhp92PkGrIwGH3_EEg
# 4          Entertainment  UCzzzrOhp92PkGrIwGH3_EEg
# ...                  ...                       ...
# 399995  Film & Animation  UCzicvxX--jNZcXMIP7Pga7Q
# 399996  Film & Animation  UCzicvxX--jNZcXMIP7Pga7Q
# 399997  Film & Animation  UCzicvxX--jNZcXMIP7Pga7Q
# 399998  Film & Animation  UCzicvxX--jNZcXMIP7Pga7Q
# 399999  Film & Animation  UCzicvxX--jNZcXMIP7Pga7Q
#
#                         crawl_date  \
# 0       2019-11-22 18:08:02.988358
# 1       2019-11-22 18:08:03.607261
# 2       2019-11-22 18:08:04.207434
# 3       2019-11-22 18:08:04.762197
# 4       2019-11-22 18:08:05.394920
# ...                            ...
# 399995  2019-11-14 22:22:34.210576
# 399996  2019-11-14 22:22:34.808370
# 399997  2019-11-14 22:22:35.425165
# 399998  2019-11-14 22:22:35.975036
# 399999  2019-11-14 22:22:36.733456
#
#                                               description  dislike_count  \
# 0       Мой ВК: https://vk.com/holdik_clash\nМой инста...           48.0
# 1       Мой ВК: https://vk.com/holdik_clash\nМой инста...           60.0
# 2                                                                   40.0
# 3                                                                  113.0
# 4                                                                   74.0
# ...                                                   ...            ...
# 399995  Same plaster job and disc as before, (Mr. Nann...            0.0
# 399996  Again, from that same early 2000s DVD print of...            0.0
# 399997  From an early 2000s DVD print of Mr. Nanny (19...            0.0
# 399998          From the 2004-ish DVD of Cellular (2004).            3.0
# 399999  Beware of Sony Pictures Television!\nAgain, fr...            2.0
#
#          display_id  duration  like_count  \
# 0       e3qGZIDcMK4       495      5138.0
# 1       11em10cFRbo       666      4893.0
# 2       Hx6TabZ1D28       605      3305.0
# 3       -a3fA6wF4rk       643     13789.0
# 4       zGpfBNAwBYU       652      5732.0
# ...             ...       ...         ...
# 399995  Grzi_GzRS3g        14         8.0
# 399996  ELQTdZOpqFs        14         5.0
# 399997  n7m2r2W8_J8        14         7.0
# 399998  I4BV1F6uFus        16        48.0
# 399999  ws6wkBWBqNc         6        28.0
#
#                                                      tags  \
# 0       холдик,холдик бомбит,холдик нарезка,нарезка со...
# 1       холдик,холдик бомбит,холдик нарезка,нарезка со...
# 2       холдик,холдик бомбит,холдик нарезка,нарезка со...
# 3       холдик,холдик бомбит,холдик нарезка,нарезка со...
# 4       холдик,холдик бомбит,холдик нарезка,нарезка со...
# ...                                                   ...
# 399995         New Line Cinema 2001 logo,Mr. Nanny (1993)
# 399996  From New Line Cinema,New Line Cinema 1987 clos...
# 399997         New Line Cinema 2001 logo,Mr. Nanny (1993)
# 399998  New Line Cinema,New Line Home Entertainment,20...
# 399999  Fisher-Price logo,Sony Pictures Television 200...
#
#                                                     title  \
# 0       ЛИЦО, КАК ЛИЦО - ВЫБИЛ ФРЭНКА! НАРЕЗКА СО СТРИ...
# 1       АВТОАТАКА МОЯ ЖИЗНЬ! Я ДОНАТЕР - МНЕ ПРОСТИТЕЛ...
# 2       НОВЫЙ ЛОГОТИП ХОЛДИКА ОТ ПОДПИСЧИКОВ! НАРЕЗКА ...
# 3       РЕАКЦИЯ ХОЛДИКА НА ДОНАТ В 25.000 РУБЛЕЙ! НАРЕ...
# 4                      КАЧКИ В ДЕЛЕ! НАРЕЗКА СО СТРИМА #4
# ...                                                   ...
# 399995           New Line Cinema (1993/200?) [fullscreen]
# 399996  From New Line Cinema [Closing] (1993) [widescr...
# 399997           New Line Cinema (1993/200?) [widescreen]
# 399998  New Line Home Entertainment (2004?) (60fps) [w...
# 399999  Sony Pictures Television/Fisher-Price (2007) [...
#
#                 upload_date  view_count
# 0       2019-09-24 00:00:00     52193.0
# 1       2019-09-21 00:00:00     46523.0
# 2       2019-09-17 00:00:00     25259.0
# 3       2019-09-06 00:00:00    142693.0
# 4       2019-08-27 00:00:00     52854.0
# ...                     ...         ...
# 399995  2016-11-20 00:00:00      2618.0
# 399996  2016-11-20 00:00:00      2090.0
# 399997  2016-11-20 00:00:00      2699.0
# 399998  2016-11-20 00:00:00     33238.0
# 399999  2016-11-20 00:00:00     13657.0
#
# [399997 rows x 12 columns]

# %% [markdown]
# # Comments about the data and the project

# %%
df.head(2)
# Out:
#       categories                channel_id                  crawl_date  \
# 0  Entertainment  UCzzzrOhp92PkGrIwGH3_EEg  2019-11-22 18:08:02.988358
# 1  Entertainment  UCzzzrOhp92PkGrIwGH3_EEg  2019-11-22 18:08:03.607261
#
#                                          description  dislike_count  \
# 0  Мой ВК: https://vk.com/holdik_clash\nМой инста...           48.0
# 1  Мой ВК: https://vk.com/holdik_clash\nМой инста...           60.0
#
#     display_id  duration  like_count  \
# 0  e3qGZIDcMK4       495      5138.0
# 1  11em10cFRbo       666      4893.0
#
#                                                 tags  \
# 0  холдик,холдик бомбит,холдик нарезка,нарезка со...
# 1  холдик,холдик бомбит,холдик нарезка,нарезка со...
#
#                                                title          upload_date  \
# 0  ЛИЦО, КАК ЛИЦО - ВЫБИЛ ФРЭНКА! НАРЕЗКА СО СТРИ...  2019-09-24 00:00:00
# 1  АВТОАТАКА МОЯ ЖИЗНЬ! Я ДОНАТЕР - МНЕ ПРОСТИТЕЛ...  2019-09-21 00:00:00
#
#    view_count
# 0     52193.0
# 1     46523.0

# %% [markdown]
# -> Video data : 'from 2005-05-24 to 2019-11-20.'
#
# -> Times series data : 'from early January 2015 to the end of September 2019'
#
# -> Channels data : 'We obtained all channels with >10k subscribers and >10 videos from channelcrawler.com in the 27 October 2019.'
#
# Idea : select the features that we are interested in, and create a new data file, that is less heavy (for instance : delete the video description)
#
# goal :
# - Explore how content variety affects channel success, channels with varied content should attract more people, while channels that stick to one category might show more viewers loyalty
#
# 1) link between diversity and number of subscribers
# 2) link between diversity and number of view
#
# **We need to define diversity first.**
#
# - Creation of a youtube categories spacial representation. Is there categories that are often link together.
#
# **We need to define the distance between categories.**
#
# **We must write low time complexity function because the dataset is very large !**

# %%
def get_unique_values(data, feature):
    return data[feature].unique().tolist()

get_unique_values(df, 'channel_id')
# Out:
# ['UCzzzrOhp92PkGrIwGH3_EEg',
#  'UCzzzZ3-icktxbC3j7hkWqRw',
#  'UCzzzUN8yvD2LRAnY-lhzyLQ',
#  'UCzzzPMh9fZHxc7gxPRB2LHQ',
#  'UCzzzP7KSHDtw9XaT-PcGyJA',
#  'UCzzyt9Z70MBX9RQAFVSNlpQ',
#  'UCzzuPi9S7NNCdkiHAcx92Qg',
#  'UCzztaOtjmaZoiLvWLagq7bg',
#  'UCzzt1esHXqs__Hrp1KugqPg',
#  'UCzzt-UNlRHbEFY3rEpFpuXw',
#  'UCzzsKg4jPGBL05t2w3HfHBA',
#  'UCzzqd0yx7h1PuC3KJVqeJgw',
#  'UCzzoJY_ln_StRVdrRX1_ftg',
#  'UCzzmGsmy8cBxmqljbVG_e7Q',
#  'UCzzgEOi0xR9SuflkXmTQv6g',
#  'UCzzfu83LhPMMuhtDVA75rfw',
#  'UCzzeO6b8v8bBt7gjSWBKzOg',
#  'UCzzbaQY1nPim5yroAjtXRTw',
#  'UCzzamhkOmpSnZ7BSBikvKnA',
#  'UCzzYnZ8GIzfB1Vr3hk2Nj9Q',
#  'UCzzY0ro-Kr3S1C0vhjhkZ4w',
#  'UCzzXsnHsEmGorQ6xAKL2sZA',
#  'UCzzXikQ7B6ZCcmOYceFdumg',
#  'UCzzX6cJ8E4C9L87PSHOweGA',
#  'UCzzVUde44MyJgFhwRc1iiFA',
#  'UCzzUx3uOjiRM-FsBH027O9w',
#  'UCzzTgcVSmq5qyZ1-ZGEMFLA',
#  'UCzzT17GEeEPojZe7FT7skag',
#  'UCzzSyCWsJpSNyhspb085tag',
#  'UCzzSPRyMYUw6IGueHr1K0Jg',
#  'UCzzQnR2e5VIgziK3SiJ6uIg',
#  'UCzzOKT1SkE7qdycJvPCR3Gg',
#  'UCzzN0bL-q5EfdolAwiiBDhA',
#  'UCzzMiZKrj0jBKEQj7L0rYfg',
#  'UCzzLIhDbFYU46T4VFBz_m_g',
#  'UCzzKrtcSbLq28-JuTfYmZDg',
#  'UCzzHicLcWJP2jagxpqebzsA',
#  'UCzzFlV_zPTha93f3K8Vf2EA',
#  'UCzzD5Pq4JHseXnZQzbBkcOA',
#  'UCzzD3izXihYOewbthyFb2pw',
#  'UCzzAXA34guxRHKnTY3RaS_g',
#  'UCzz9_nzdbrxnErTZPZdZ-cw',
#  'UCzz8RXWvbxmaSsT6qNfX9bA',
#  'UCzz6z566lJPtjqKOPUmHZKQ',
#  'UCzz6OY86r6OJmVvI_H9Q1RQ',
#  'UCzz6LVzLtqwfML8t8H0rF6Q',
#  'UCzz0tForkMrJgZPAC58gakg',
#  'UCzz0qHbaMVsBHhwt4M21nnA',
#  'UCzyzsEginRgn2RrEsUM918Q',
#  'UCzyxWsAmXccLSFO4DLVoxGg',
#  'UCzywT7kUeoJFnxuC6m_uLiQ',
#  'UCzyuszXJUbY6w-S_t3n7hNQ',
#  'UCzyuclWm7yANjLYP4vlcleg',
#  'UCzyuZJ8zZ-Lhfnz41DG5qLw',
#  'UCzyu0YDMQB_5iSGPOXECcHQ',
#  'UCzytbADuggStj9t25taatAA',
#  'UCzytaIO8NFjmX5Deydhw5Uw',
#  'UCzysEHp6XaSBji4FEjYn1LQ',
#  'UCzyrOOWedwS1K5wUEUczc-A',
#  'UCzyrNGiPTivg4sxUrRRmbCg',
#  'UCzyodqoxqQlHj_KlMVEO62w',
#  'UCzyoNyddDK81ZiYkoFWrQsA',
#  'UCzym8ZiGEf186PlXw77voRw',
#  'UCzykucNJiAXETVEG_u3GYHg',
#  'UCzyk5gg98nCQ5j-YSKr-w5A',
#  'UCzyjTSS_L1ttmOq-Zqc_Mrw',
#  'UCzyj-fJji4hwggRGQh7pppw',
#  'UCzyhU6QP4_HRLR1aoyRg1ow',
#  'UCzyh48nlUsGIzK6mOrtyoRQ',
#  'UCzygYq7-4TQokE5ifE8L4aA',
#  'UCzyfkcDsgePLd09B-8LxX0g',
#  'UCzydWtf2Y5XQqKeEnO4gOvQ',
#  'UCzycs8MqvIY4nXWwS-v4J9g',
#  'UCzycaikz6yplScJRPJwEpzw',
#  'UCzyc6CQytU0sbcakYWsn_jw',
#  'UCzybXLxv08IApdjdN0mJhEg',
#  'UCzyWF5bJDp04AWV5bolZ2uQ',
#  'UCzyR6O1o5fjdwvmKOaMOBaQ',
#  'UCzyOUOhPm7Il_lUVGp02pjw',
#  'UCzyNtfiuGVAJ5Fo5iHz0jbQ',
#  'UCzyNditGoG4bXlyg3Tfx7YA',
#  'UCzyMypIMUep5W0J3R3PC87Q',
#  'UCzyMqWhjqFkxxdM6C3UYsOg',
#  'UCzyMe5OSJ-Og47XrYFJ17ag',
#  'UCzyIdvT0wvCGAMc9dL2B3Ww',
#  'UCzyGcJEKmThmhcvjuERpumw',
#  'UCzyGb3cWMH9qMafK4QiE4wg',
#  'UCzyCQrsmHoINb-E4niKgqEQ',
#  'UCzyC4di_FkW6aRCRxjL1KYQ',
#  'UCzy8SK2F__OW05OFNzFbywg',
#  'UCzy624YaBOMDHbWsFP8p8-A',
#  'UCzy5oima9fL7WwsBeZIzxaw',
#  'UCzy5TSKpmhWTKpvlH5ReTvw',
#  'UCzy4SDVnFsMgws1hPyYAvZQ',
#  'UCzy2p-WVd6dCPM9LRy0o9Sg',
#  'UCzy1ev-3tCoIXJYLQb3156g',
#  'UCzy0fNJRJjq3HwEv6GYF1Cw',
#  'UCzxztcLww-jPvE5QbFC3n0g',
#  'UCzxoagQ75d40OOdNsZFlMpQ',
#  'UCzxn731KM8sfH_LS7-ekbTg',
#  'UCzxi6zrtqMOxGj7_CQEM__Q',
#  'UCzxeUZZFIhMtoYRwspfic4A',
#  'UCzxcdV4g34w66wZsTFR7krQ',
#  'UCzxbrtLCkQYPEWohSkwSAbw',
#  'UCzxbp5h6lUD8yqF4MH-ICuQ',
#  'UCzxbCDm6R9Tm_Ae_MWSCaiw',
#  'UCzxZskOWONmKwgHSdNatzog',
#  'UCzxWtRVuke4GnD6JWQ72U4A',
#  'UCzxWFIJccSKOfRmLiMOs-Fw',
#  'UCzxTzOeoy-DQG_3IVwnOo5A',
#  'UCzxRv9BtqrM946JmaMLtv_w',
#  'UCzxR9hrjzqZVq7imo_y37-A',
#  'UCzxQ3Fx5K8VehnAdjY_FSlg',
#  'UCzxP6b3YmADl4G4ro72UVMA',
#  'UCzxLOMj3HTM4yKGNtaG34-Q',
#  'UCzxI1sTd3a5ycinoHzyG9lw',
#  'UCzxG2q7N8jgMXaxjE6iVTDA',
#  'UCzxFYh_p2q8J8RGyTZJMjig',
#  'UCzxFASChlf7NOCh89gGZ-Yw',
#  'UCzxDOqKrg3sHcatf-7URUMw',
#  'UCzxBVWxydkXAlHGrPXRZzjQ',
#  'UCzxBCMcgqe9kFZL5w7HxRDw',
#  'UCzx9exbj1Zoh51o2Sr5rxBQ',
#  'UCzx8WFdvYyQgPuLY3XSU83Q',
#  'UCzx6eygGhURvNcZud_zTh6Q',
#  'UCzx5sed5ne8KjPa0KJn3gdw',
#  'UCzx4FRXyIE6aLP19baAcjhQ',
#  'UCzx46lLqEb8iTpumrsd01Lw',
#  'UCzx2fG10WHhc5Xs7GjtGqtg',
#  'UCzx1ee7FllS2YBaobO5YZmg',
#  'UCzx12nFRrzcS4hOi102DY2g',
#  'UCzx0a_X3EW7I4cm7uedTG6Q',
#  'UCzx062pqzC4MH6yedufVDMA',
#  'UCzx-2x9xINGUNhOGqGqzvIg',
#  'UCzwzzxrz4CrsuEls_Q9wM5g',
#  'UCzwzvW42LCniaNXxwGJDT5g',
#  'UCzwzVFgZa3AS9IPLPfJjf1w',
#  'UCzwyWaqF9ofIUy4EU41GZiQ',
#  'UCzwyOzCiZUtVElRdyZQx68Q',
#  'UCzwyF_IcyMP86ilsmKD1Pcw',
#  'UCzwwBSRb4pYlJ4DIVh_Am2A',
#  'UCzwvZtuFWsp-yC7H2tTx9WQ',
#  'UCzwvRsqiMdBdf1jjePraHxg',
#  'UCzws0oxeiKukauSmMkvioxA',
#  'UCzwrjVlnMRynB80igUyAioQ',
#  'UCzwp1viBuufTrpx5jyNuYYA',
#  'UCzwozfj5iRDcKl032IhjGUw',
#  'UCzwoOdOqB-eNaKyi2SsEfmg',
#  'UCzwnUEmVsMOrtR2rlLkNnSQ',
#  'UCzwmB2wn8Slp3hko2Gpj2iA',
#  'UCzwlnJ_NUsmin7DtPRDNCHg',
#  'UCzwl3WOpGBUoy6bbyV9Bpyg',
#  'UCzwkdb9w47TR2pY99GwXf1Q',
#  'UCzwhGJV9o4KTPD5Nq6GPeqQ',
#  'UCzwfTKPBtfzLUn_qeDiEw9A',
#  'UCzwe0YWblwBt2B_9_d-P44w',
#  'UCzwdd9y7ehpI-DE9Ed2sT7A',
#  'UCzw_l_OixAnsdrcg90UWSDw',
#  'UCzwZUFp8UGZ1iV2-M86MseA',
#  'UCzwZ7w6R3fMBni-S6Zlkl6g',
#  'UCzwYZvqXQ9ILyA7P0ojn3UQ',
#  'UCzwWnHB-ha-7k1GbM4xlEAA',
#  'UCzwLPqK5wUjrfO9LklPW8hw',
#  'UCzwKe9jWNVr-C2TbtoxfHqQ',
#  'UCzwKYrHroAYBh4bOrgovtMA',
#  'UCzwK53-7a_HcREmJLXD0Isw',
#  'UCzwJlXggvorZSvyWwZJ497w',
#  'UCzwFtqG0_CJW03ahciq-XIQ',
#  'UCzwFZOhCfCZTgLruMz_RWCw',
#  'UCzwEJTQa7wl0AboBYbrKr1A',
#  'UCzwCkeBYDKAR7jpk986MYtw',
#  'UCzw93Ly9UW9z9tnRXaS9k1w',
#  'UCzw93BqU8XR8H55pNeQXVjw',
#  'UCzw8yWPDE2OU2g5W0REdUCw',
#  'UCzw4hbQIePVtyJQzE_F8QDg',
#  'UCzw3jVcRBh3MjetempQDveQ',
#  'UCzw-tVREl-JlkHN4xO9Hhfg',
#  'UCzvzLJ5Jpb0XhvYsT5t7ZbA',
#  'UCzvtdS9xJYZfJFosAvk9OXw',
#  'UCzvsu2bRP8Asfv3lb-pz_aw',
#  'UCzvriNT36xQ9XZ_bEZ7XPjw',
#  'UCzvrcwm3nG1kCad4DIzng4w',
#  'UCzvqf364TVLEX3sWA07sssA',
#  'UCzvq_2THJhueXOP8JdAO2-A',
#  'UCzvpugUvLq1mDulO0bb0Otg',
#  'UCzvoUDoDu-cKIb11rg4ODDQ',
#  'UCzvmkcHWA3ow0V9mYfH_MTQ',
#  'UCzvmP3E4MNawV4Uek7512fg',
#  'UCzvmBKjsw19OY5RBauMtVpA',
#  'UCzvleCgTB-wNHtmN7he-hqg',
#  'UCzvl_gwH082JS1QFyL00gEA',
#  'UCzvja2t5Ppv5incoaqKC-Kg',
#  'UCzvh--VPr_1kvsobzmLqlsw',
#  'UCzvff2Jln6aXxli7dXJLTPQ',
#  'UCzveVy4jC5E2kxQ6GQEGxOg',
#  'UCzvdhZxx0IXwIuFltpHoi0w',
#  'UCzvd3SYAZEeDvRweVKa-YDQ',
#  'UCzvc6tzu5M0PY0XYZaVePqg',
#  'UCzv_k_SHufkfkXF6RfFTFTQ',
#  'UCzv_NLpAyMz5IMNfCkuCoMQ',
#  'UCzvWAx_iVxuwhpMF0_DNjTQ',
#  'UCzvUpKP3KVEPX5Th0s3dTuQ',
#  'UCzvQ_89MScBaY_rXTofgfIw',
#  'UCzvQZYWPZY0__o4wprFeP4A',
#  'UCzvNkLJ8NJdiDFeqpjaMOmw',
#  'UCzvNdXKwQDN1Bz_1-ROJLSQ',
#  'UCzvMM0Cw7QWLf5vdTtXUeWw',
#  'UCzvKgOybjR5NFI9yB1pcP9g',
#  'UCzvJphCQQOcQIYd6nJAtG0w',
#  'UCzvJPKT8IYd6vi1KeLtacEw',
#  'UCzvJMUdiq83refanctkG9IA',
#  'UCzvIVSp5PufTdhZjgn1LSRA',
#  'UCzvEFIMbk0a5edd4SlWN-wA',
#  'UCzvDSoNrl2Uva7t_Z936VUw',
#  'UCzvCpVRrffLPNlNN2WNWKQg',
#  'UCzvCf_q10UZkUJE0lOav0ag',
#  'UCzvBMFhS0gqjx1rA0bswiHg',
#  'UCzvB5GjzKymIUNiHMiyFvng',
#  'UCzv7f9051eDTAaX6rhbtxtA',
#  'UCzv6XstloIRo1EkzFvP1n_g',
#  'UCzv6S8busYgfdfca-_JvG3Q',
#  'UCzv51oYbxIKw1OqHLyCPSKg',
#  'UCzv4mCu3YS_9WjAWSt9Xg9Q',
#  'UCzv1t7voB-bxMmXLysT4h0w',
#  'UCzv13f5KtfMbf_RLfS2JPmA',
#  'UCzuxOmvoFRs6d4qH3QEgfqg',
#  'UCzuwx0fRXDejdaA9DNklwtg',
#  'UCzuwV7c9GFAgGt8hRT48pyw',
#  'UCzuwS1ll2HuQ1wV-tqf43KQ',
#  'UCzusrs6aDzKs9mfAWf9SG9g',
#  'UCzuqiazDmKtwLyE3Kb7Mq0g',
#  'UCzuqE7-t13O4NIDYJfakrhw',
#  'UCzupznQsFIZqwZUIytDhzXQ',
#  'UCzuolFXlT-MX-FCwXz9x5HQ',
#  'UCzunKEAlddjLfVVceIAXBSg',
#  'UCzuj9sYnHfYZ_JJAanBnAFQ',
#  'UCzuhnV9yUolL8Evdd_nhAaA',
#  'UCzu_vpLNvYF8fsp2Gy_6flQ',
#  'UCzuZWTVU97w9TUGpPQYfIeQ',
#  'UCzuX1QhuerJ9Kw-sIlGVznQ',
#  'UCzuW84oOedCNL4gY7R4hR4w',
#  'UCzuVmvgn3d6WLs3-LbpMkWg',
#  'UCzuVhGRaRKJ1Kkk2s7f9Caw',
#  'UCzuU4hiNvpJKIUpOcMdnj1g',
#  'UCzuRR5R_kEFHuf3SG-8-FKQ',
#  'UCzuRLPegnu6m8HZ-qkWEF1Q',
#  'UCzuOe5qccLzP9CQtRnFVB4w',
#  'UCzuOCMm4bYELiv-DZAgfm4g',
#  'UCzuNZXic_rWy1ju8SKRlRWA',
#  'UCzuNVbcZlDFRtoYQVrigNtQ',
#  'UCzuN3Q6ZDE5gX59ZH2ejZIA',
#  'UCzuLUZV3Y_X6cDz7SUpqrtw',
#  'UCzuKzSNb8hGV9DsqIBUb79w',
#  'UCzuKp01-3GrlkohHo664aoA',
#  'UCzuKOFUSES5CE-nKUpHP0Mg',
#  'UCzuJendDw8ug_rVEI6oc8Kg',
#  'UCzuHs9vu5MswahKTT1iClFQ',
#  'UCzuGtMl2IlPB5ljgwkLJ3cQ',
#  'UCzuFRkWj9156yqVO8eat0LA',
#  'UCzuEQS2UFiYMnHfThSDulvw',
#  'UCzuDpN8z5xQeFDBOD6Hvf2Q',
#  'UCzuDRmmuiqab_dHH3LWE2kw',
#  'UCzuCW8olhfXml48tunQBKpw',
#  'UCzuBZoEEDGhyzo5g0vaCHOQ',
#  'UCzuBLmu_0tCIuJW1mTWEqMw',
#  'UCzu99u5Ed40VtiuzYgK_anw',
#  'UCzu6NmjTlDBpw_0gcazyqYg',
#  'UCzu4yAAQbrFZ5zzT4DG6-eg',
#  'UCzu3zIZ3quI0U-ld09BPzpw',
#  'UCzu3cLKzKqEX1JjEqwjuHYw',
#  'UCzu3BloRGPNnhs6kr8R8Gfg',
#  'UCzu2HSibuCPslOpyebGdFXg',
#  'UCzu-xQeFFtu0seRd5hPQ_eA',
#  'UCztzP_m4bgGt-rBXAPZTuVg',
#  'UCztyVCXfSjXdh3ijZ511mSQ',
#  'UCztuBb7p2XYrxcKLw6WB-nw',
#  'UCztsMiNtSDxWDo6K_1GAiJw',
#  'UCzts0MUNkxJlvBDCMnH30oQ',
#  'UCztp7FHZRT_tCBBoLVa1lSw',
#  'UCztogSMGMu_EiJWwFbZIPBw',
#  'UCztoApuaeVF3RhK629T_U0Q',
#  'UCzto116LY27fKEohktdIJQA',
#  'UCztn2KrX8KKizSpvzkZoDtg',
#  'UCztm-DxaKV1EpXSVxlVvbeg',
#  'UCztlu-4ndJ1CBGPbqofLmPg',
#  'UCztlt79t8cvrtLpnoIXz2Pg',
#  'UCztk4LFUIk4Ao4TCvpdnDsg',
#  'UCztj52EbDSOu8FrP9HNtBfQ',
#  'UCztc5h1xbTLfutYRh6rD60w',
#  'UCzt_dSqUixh0lhueFtqh2QA',
#  'UCztYfDjop8Vih1QTkMaQczA',
#  'UCztXZVQiVSqoDTC9USNPeqQ',
#  'UCztX82Y7pvRiKnHhlhp9zIA',
#  'UCztSwKRcz_jZC4KcGVZH69w',
#  'UCztSIZEGBfWfC3Mq63QXnsA',
#  'UCztPzOfFGVm3weALhe9ovSQ',
#  'UCztP5id1p1JTGefZjHSbW7w',
#  'UCztNWFOd5hvLj3qXx3sq_iA',
#  'UCztIh384xM85AojZaW82RAA',
#  'UCztIQx4WxIqJaAS_9BN4FTg',
#  'UCztHe2YmTLuIL-cVaH1DxZg',
#  'UCztHdGwzRkxXlJe3Vxi11CQ',
#  'UCztGwJPv7s9pXm4mrHT3ecA',
#  'UCztGZlJJwLlwyadsSVr3-ag',
#  'UCztFFeqzS3TjQvV9FzY5IDg',
#  'UCztBLNmyKPZGlk2iGVljWlQ',
#  'UCztAopfCNqk7dBMTmmN9qvg',
#  'UCzt9gB3XNQYs_2UHvolUZog',
#  'UCzt9W_EwMdscbLLLjGLhLdg',
#  'UCzt8j2oNWY29DD9TG9mhMmw',
#  'UCzt83aKE8MSqyLxxKfKVH8w',
#  'UCzt6qZOzbKXlTDr9fhd694w',
#  'UCzt5gFimivXK9kZrWGSwsiw',
#  'UCzt3wUqBZsIUYeRDIaIMF8w',
#  'UCzt23hz4ZEVnJTb8izL31Hg',
#  'UCzt0Em886F29JyUxbz8oaEw',
#  'UCzt-FIYMtaequzIOtppv8NQ',
#  'UCzszRaJa7VomcD3yzd9IeDw',
#  'UCzszIh4jH06kYp7k_DxhH5A',
#  'UCzsvSXSk01GJc0QDUt7eYiA',
#  'UCzsugbP3D-dsybrYAHkfMGg',
#  'UCzsrTJtY25ZPtl11KhiVHaQ',
#  'UCzsqnCSI07gH29p2gE7ESsQ',
#  'UCzsqJV6eaQPlmaXgmYaw9kw',
#  'UCzso0nsdJHgbnjMI1rJpp6A',
#  'UCzsjHlc0WRwZYwlinsmtM4w',
#  'UCzsizX25bx5_iUSM0ztdBFg',
#  'UCzsipLeHCLiFAB81hfDjnmg',
#  'UCzsgTo7_VOtDLlhTnK0SdtQ',
#  'UCzsgDnduxj3eJnLKzrc8pRg',
#  'UCzsez-G-ZhfxT5RLNTrtI9w',
#  'UCzsd4-oyHhNbAXfceOQ5HTw',
#  'UCzsd3xFjM6QtHCySd0oPr7w',
#  'UCzsafKivRHDTExVupS4nPDA',
#  'UCzsaQoeRJjnnaQrLWDZ071A',
#  'UCzs_sZFpKO41oOFy16mdqmw',
#  'UCzsXeQt4f_O6ABS8IiqA7Lw',
#  'UCzsX6H1DlbS7BbnSzH7Y4cw',
#  'UCzsUO7Ns8QSC29iaCoepYlQ',
#  'UCzsRJHtbT5cG2lthJD3lQ6w',
#  'UCzsR3ghNLC6qCQrHlAKlGVQ',
#  'UCzsQf6eiWz4gIHgx0oYadXA',
#  'UCzsPxrgq-aupKyqJsQ2uc4A',
#  'UCzsNSHDW2iLLdBtcat5w0aw',
#  'UCzsNQvqs01ShacBpieecFSQ',
#  'UCzsMguDJtmra1sJl7yNhhWQ',
#  'UCzsMKR_d_O1U-DNDhjWkkAg',
#  'UCzsKCFGWpOk9gxkOjORRkZw',
#  'UCzsJwVqrumDb2JziGh0-A6w',
#  'UCzsHHD-vtGQAB4XNWTo2xbg',
#  'UCzsGmr4VmJvF3yXVNe2-otA',
#  'UCzsF1ghKHeif7AmTNlRYAzQ',
#  'UCzsEaoavFxLqwpNNBGhKLPw',
#  'UCzsBiPHqjFiGPVO9mCH4N9A',
#  'UCzsBcdCIf7XrDzSft4774ZQ',
#  'UCzsAC7IMKbiuky8IAFNd_dQ',
#  'UCzs8bEZtZR4RkV0stTydurg',
#  'UCzs7yNDP-_nR6hA_tNxi2Gw',
#  'UCzs7ZW1Car1DctJK3_Xo-2Q',
#  'UCzs6lOMCW6ZaLPoWQfzPBiQ',
#  'UCzs1BmuqwJQfUuXtUav1znw',
#  'UCzrzsClnsxBuzBuYqpxL1-A',
#  'UCzrzP91877Jv34lXV0_idgg',
#  'UCzrzOItQbqY7akga3rPRoMw',
#  'UCzrzKRpIYfxWrd7KOiM7Mfw',
#  'UCzrtiGzcopa29kr47YL0iAQ',
#  'UCzrskTiT_ObAk3xBkVxMz5g',
#  'UCzrqnYSFzfIqe5HAwR9WCRw',
#  'UCzrouHloGADxMW7olHyPbHw',
#  'UCzri8z_k3E5UhVjYkBEoW2g',
#  'UCzrhtkj7E-MIAZ2ltngK1vw',
#  'UCzrh2s9Vu9wUBf2Y2iIYcgA',
#  'UCzrf-xxawcQ730_0UEVSrfA',
#  'UCzreeLY8gsp8NoqhG9OnqIQ',
#  'UCzrdtk6p4SaakMz2ZmOkCQQ',
#  'UCzramHfYKVNDcoee1sTbbfA',
#  'UCzralVi6mA-Zq3WGVye9Ycw',
#  'UCzrVJ3pI6XeIHx1jUQKKNww',
#  'UCzrVDkt2zx2JFfJb-ipGk8A',
#  'UCzrUlkFzxLq8TbWvGJ9uHAQ',
#  'UCzrTRRYe-m8zyd5FNMLXWAw',
#  'UCzrRJfoNYDdx9yHkH8ISubQ',
#  'UCzrLrWM1kM6YpVxyxcJnFNA',
#  'UCzrL7psSVpReJ53ZUrAWX3w',
#  'UCzrK_2Y6GOAR-kpvdPkyl_g',
#  'UCzrKTE2DW55HkfvD9EsX0Kw',
#  'UCzrKSPMhDNBatfoxcuKj7vg',
#  'UCzrG8j-dPQTNl7Hf8XAuN6A',
#  'UCzrCDlxEezcZzwV_FQqpKMQ',
#  'UCzrBR9Zo-bobJFsL9CDjTiQ',
#  'UCzrAEXNcWK6v-KpLc0Vpfag',
#  'UCzr9bpOlVyjxBjKEb30aPNQ',
#  'UCzr8ue385BLzBsCZlUw_B3Q',
#  'UCzr89W3FtxsFdZDSGqrjlwQ',
#  'UCzr7vtwXg9kdgmMzGWiFcIQ',
#  'UCzr7rCjS7DMUyhB4377fHSg',
#  'UCzr6gD2gZDJL0wdoV43jqog',
#  'UCzr5_Y9YO_5rfLLsqsbAAgg',
#  'UCzr3Uag1SVoDv6IJzbURXQQ',
#  'UCzr3JZ36h7Wh-OcTk0TYKGA',
#  'UCzr30osBdTmuFUS8IfXtXmg',
#  'UCzr0iRJgtLNitmAl3U7A1Tw',
#  'UCzr-PyKUTPosDadxqMHtoTw',
#  'UCzqyss12CyV4jZtrhpksF4Q',
#  'UCzqwVVF9_Pw1WZrkS0z5P8g',
#  'UCzqvFeCBcrKhxxFMz5SLGFQ',
#  'UCzqtgselejnGu7o2tp4D3ZA',
#  'UCzqt-mkqxVkvu6h64i3Hg9w',
#  'UCzqpZ8XdZsLBGNYKbEZn-TA',
#  'UCzqoDByLnCcxOxdXyZWNuVg',
#  'UCzqmBflQBorUStH5b4V8bJg',
#  'UCzqm-ien6aEj8CSfafHCBzw',
#  'UCzql6CQhTnJcoa3WRIrNR3w',
#  'UCzqk9ulAfmkwUgIBtUhCH-A',
#  'UCzqh_8hImIc9fhvUu0oVC8w',
#  'UCzqcfJjCO5C1zUmnxFRGvzg',
#  'UCzqbfYjQmf9nLQPMxVgPhiA',
#  'UCzq_Ge7cQHcEDpdXL14DE4A',
#  'UCzq_6LivOi5mU0VoP1g2c2w',
#  'UCzqYD2rJzdJqHBGVpu8ETag',
#  'UCzqXUVXH1kxi_tfhdwqWiQA',
#  'UCzqUtWatazzSd63ZgAQQwVQ',
#  'UCzqSiy4Ck1M_xCfQxmSO6kQ',
#  'UCzqQgSFx0gZwnFK1h-feQ1w',
#  'UCzqQPiNga359uISQxuKO1Fg',
#  'UCzqMAmNP2YG5i6TFjKeAX-A',
#  'UCzqLpxkldvcMo7408uzNDlw',
#  'UCzqLKD4u7A7BPri9GH13Shg',
#  'UCzqLA8MpeUSTOtlrTNKbbNw',
#  'UCzqKN5twwF71FzegCtL45KQ',
#  'UCzqK8Ja6KPdTQTLfMg0QNRw',
#  'UCzqJnkXM5Kj4YGsMywEe9Eg',
#  'UCzqDn76Q7272NcY3DufBirA',
#  'UCzqCtwJopDTdlZYcEYxaPPQ',
#  'UCzqC4nfDguNTDY1AWFdjH2w',
#  'UCzqBrscCWmHVSdan4a8TyDA',
#  'UCzqAydbYsJFVT2yR6JNNfMg',
#  'UCzqAxqTTJLI1Fdc9_tMjjwQ',
#  'UCzq3tpwoKica7nf7cXYz0FA',
#  'UCzq2Go7CfANoFnfIps9CK5g',
#  'UCzq1xxLmhvFfYUzKM4M8OyA',
#  'UCzq0VrH8X3x7r72KDkDgt3g',
#  'UCzpxGVyYmCH1_lFjlQLxdYw',
#  'UCzpwNlWjeaWASjhbhRCEZbQ',
#  'UCzpwLi6yJjhjPyca7VzXbnw',
#  'UCzpvSWz3VFZpeFeitVsybWg',
#  'UCzpsSWCmIXGqy2pCoACVrNQ',
#  'UCzppJHq0IWzKezQBzJdhbvQ',
#  'UCzpnWwwKDvMt8Bwa4fvjCEg',
#  'UCzpmmzp7KnAqZsdA4YgkIcQ',
#  'UCzpl6CJP6lo5vjsEAeIHnsg',
#  'UCzpgy7wABX-YqjDWrQ2NJRw',
#  'UCzpdgMjpMUunL9ObB6WZxPQ',
#  'UCzpc1yp0a0VdJEB1kO7Cw4Q',
#  'UCzpbIPE0e6cn7aBzNkgOc9g',
#  'UCzpWsYpes5XK2rO_s01c1Fg',
#  'UCzpVHRTF6eD0z48h0TAaq5w',
#  'UCzpVBvuIfhncmI7JDwBCOyg',
#  'UCzpUyN2NZSi02f6RSIArTdg',
#  'UCzpSo_7uynC78g9m1YAwAiQ',
#  'UCzpQvNnyoKgpu0lJdeXbFmQ',
#  'UCzpQlPzEF117cTHhhnzSbXg',
#  'UCzpPEXXRndTUNdYq1sPEogw',
#  'UCzpOhrFzMfza8O0a7iGcneQ',
#  'UCzpNH0L4xxy468bvAI8Rd-A',
#  'UCzpLpQVToK4Bre_oLitS_AQ',
#  'UCzpIDuZIlUg7V_vcyY4c0iw',
#  'UCzpHPmpnV42DxZeArr2twUg',
#  'UCzpGSici-H8VtnhCPp_b3Yg',
#  'UCzpGRbJ5MhXnQa7E3pPq42g',
#  'UCzpFUDyb85qA2iikSiiOxjA',
#  'UCzpE3f6Giwdh6eN7Wvq_KIA',
#  'UCzpDMOsh78JkOqlHtQu9OBg',
#  'UCzpCiV_jWA7yDrnSWVvTZag',
#  'UCzpCc5n9hqiVC7HhPwcIKEg',
#  'UCzp8QlVd_hDLfK1LMLDu3dQ',
#  'UCzp8JDCwl1fZ6kaazRjuDdg',
#  'UCzp7Fl6-GS6PejX4Pz8RNHQ',
#  'UCzp595OEeDeD_23fUzjEfig',
#  'UCzp4_5BLGTG83u_xhkPSydQ',
#  'UCzp1kQJhgaAZZ52WkfQWu1A',
#  'UCzozMcF1kcR9dzsdEkRHdaw',
#  'UCzowoceNe_ArvkKKKZT7XVA',
#  'UCzovgO_F7DMfAE_1Bc9WQoQ',
#  'UCzov4EBNNkouOLxknnP1Q3w',
#  'UCzouBx4GEEAnm13gpvcL9Rg',
#  'UCzorU4CduAeMvf6Svh0BxHg',
#  'UCzorFJQFaQILd3zSOf3CoBg',
#  'UCzolMvIqyoK6hV345m6FjTg',
#  'UCzokrz1qNXmO9wNYsmP32PA',
#  'UCzokgx8hD52374H3BDQ70SQ',
#  'UCzojIVK9YrFhx594i31m6uw',
#  'UCzoinqTgfEaQsKFFi9Tdmkg',
#  'UCzohOoSdMK84eZ1VgK1jnUA',
#  'UCzofNVHFCdD_4Jxs5dVqtAA',
#  'UCzoepXsuEq_rycHius2yMng',
#  'UCzoedGkoOFs6ZrllTr-UWUA',
#  'UCzocLWhHcs0sdM7lOCJUnlQ',
#  'UCzoZaQca_SB0wxK-iSI_16Q',
#  'UCzoZ_aiAcpM7F4X7Zimnd8A',
#  'UCzoZCLBb54xs2-42h0l6fZg',
#  'UCzoXINOP7oBShGPv1XGCeOQ',
#  'UCzoWt9WjbfWghChP1aB3sjA',
#  'UCzoVL1aVjec7YKPeG59xKFg',
#  'UCzoVCacndDCfGDf41P-z0iA',
#  'UCzoTGbThLxLYmXA9A3QUTVg',
#  'UCzoS4T5cCSlvhj3KKtjOUNQ',
#  'UCzoRptzLmplt6iDW-6AuHwA',
#  'UCzoPv59-YuYk_0cCIHWBBbQ',
#  'UCzoPb9sKVAHd-pIzv9RGGRA',
#  'UCzoP7l5bzSzi2gUUNn0I79w',
#  'UCzoO74VMQKXhbYJe7RnT1pQ',
#  'UCzoMKoGaZXlfLhRkYIOpYlA',
#  'UCzoKpIaA0Xax6SxFhUUogEg',
#  'UCzoJd2zxK2Aa257Kv-AXytA',
#  'UCzoJ5RcLr3Gg1TqW5UuyzYA',
#  'UCzoFjzSkbrDD1GHsz2YNLig',
#  'UCzoF9naoNs6KkR_9i7cGE3A',
#  'UCzoE2GeGTIcSiBmLoOLYsWQ',
#  'UCzo8vOLvW_vCyJI351ZgVKQ',
#  'UCzo8bepQxJKDGm4zdbr1Crg',
#  'UCzo5sreD2cVGu2T2mNu__1Q',
#  'UCzo4OXE8JxogJHWJ2SypiNg',
#  'UCzo3uFuIpcilqHoqz_X1Z0A',
#  'UCzo1bDF151FNwtlOwy0LvYg',
#  'UCzo1KeoL1qH0IwxcQMN8xxQ',
#  'UCzo0tuJ8RVPpHiaS5LPwa1Q',
#  'UCzo0peb9wMqRiONEu4h6gOQ',
#  'UCzo-AfTSQT5kdpa4Qvc0GQg',
#  'UCznza7zIGPvwmOYgSemgMUQ',
#  'UCznysWhPCU1NFq5ANskuXig',
#  'UCznyeo7l2Bh7JtcuTRyf30Q',
#  'UCznv7Vf9nBdJYvBagFdAHWw',
#  'UCznpqp1WMxEUasor2ih6uSA',
#  'UCznn5A6cfbl4thtPgg91o3g',
#  'UCznk4o83WjKFCwEZ8th8wHQ',
#  'UCznjlQmc9z9rimWJiFFpKtA',
#  'UCznjhyfYnv-w-TgpZs4J7Mg',
#  'UCznibittbFHbwdDd5Fy01yQ',
#  'UCzngBGMPYbQqjqpWVt2CmEg',
#  'UCznbONAYUaiFlDOCRku9mOg',
#  'UCznb5kfAArFqbERQipLd5hA',
#  'UCznZ4Pf4oPQbBKLJAXGkWLw',
#  'UCznXuWp59-geC7F-jaF9_2A',
#  'UCznXfC7LthNEPUSvDydDPAw',
#  'UCznVe3MnNBPvqHDNM86771w',
#  'UCznVM0EC0LnGxBZLwTqRIhg',
#  'UCznT21KrguXFbNbFnHBBA6w',
#  'UCznSv6m77cxVkhmRwe7-E0w',
#  'UCznSJXkDdFeQP-xoFnwPIxA',
#  'UCznSBwEKa4xU8HmbEXCv6Yw',
#  'UCznS4Pk3VcTIfDUuWrQtdzQ',
#  'UCznRyLyXK9QWHs05PK2MGBQ',
#  'UCznNKu0GrKrQEvKJd7oXvNw',
#  'UCznMlH8VIg2K8BK46Ouk_Mg',
#  'UCznM0Z06Lnw0ZlJFBuvIcKA',
#  'UCznKDeQNmQafpGRBkhM39Xw',
#  'UCznHiMUNK4ZKtNrKEdIhwfw',
#  'UCznHh6gk3ewFhaTZtdQFWWw',
#  'UCznHJIMykzWBWUKwqeTHO6Q',
#  'UCznDAyKMlYxPe-RD7JVp2hQ',
#  'UCznATcbcuI4_DeLYL4zssCQ',
#  'UCzn9oVj62EFaJHjQcohwbmg',
#  'UCzn8AgRWkAPWLEQ1Fvk2RBQ',
#  'UCzn6jxg-ZY3QaDN-6Q5FQEg',
#  'UCzn5ejzfT6Y_C5VK8HvKHdA',
#  'UCzn4rRA4bdSvO0y6IctilSw',
#  'UCzn450ADyB762nv4_PiIs8A',
#  'UCzn3pG_eaZ30myAslyNG0cA',
#  'UCzn1Vmj88LfS5tVQFNsKmbA',
#  'UCzn11OVU6oAbdVV0HNVp_UQ',
#  'UCzmwnZ_ZElg6kuE6e5QS4pg',
#  'UCzmwJPZkijIfRCAYQkadJ9g',
#  'UCzmv9OMLNDBWehv2o_qAeuw',
#  'UCzmse57eZukjyAwddOLA6Qg',
#  'UCzmoc5cHCQyOUHEREjXE3FA',
#  'UCzmoXWDBrbeYgZ_JGrGjqxw',
#  'UCzmoNHZMM-0Dd_MtVgneTPg',
#  'UCzmlqs4GEH8ApiN8bswdlRw',
#  'UCzmlnH8vDQHoEb2TrC0WDCg',
#  'UCzml9bXoEM0itbcE96CB03w',
#  'UCzmdRCMU94p_ibT--5ik6Vw',
#  'UCzmbgeppe-nw7EfY8Nm0Sng',
#  'UCzmagS2JwfR2li-COH6ixoQ',
#  'UCzma2ToW1-p5N2EVn5Mf2Bw',
#  'UCzmZtDoRh0zRTTuxiw3zJZg',
#  'UCzmXCsPLxf8VemA4hXiDHOA',
#  'UCzmVSWnVw90KayviD2HHvBA',
#  'UCzmU-b586ACAcIc2guGoLKA',
#  'UCzmRLWx1fzaBy0D7kCfOn4w',
#  'UCzmQURLJn3l-8lTa1nNEI-w',
#  'UCzmPXuVPCFLHt1GYjbRWlqw',
#  'UCzmPOu0RFz-xdVl9QKHrc7g',
#  'UCzmP669uVr0psjtftqdt4Yg',
#  'UCzmO2w9-4d0-YyT_JlDDM1A',
#  'UCzmO1y59FhxJs_jywVyX3sw',
#  'UCzmN6x2tl-OaQPvUwesoh4w',
#  'UCzmJzwJst40htyEfgsyVWOQ',
#  'UCzmJx6OxhbuxuhzUebSBWoA',
#  'UCzmHDRW_xdBKdhehd6y8gLA',
#  'UCzmH6y20bymrYBcO-vzgZzw',
#  'UCzmFiOVWBFLymM5LWM0QF2A',
#  'UCzmDDWDw9N7aB5Q9IWvQKfw',
#  'UCzmBqpZwmuQquky-6pGuwDA',
#  'UCzm9a0JSb8MZQfSjuQMHBpg',
#  'UCzm7s30W79vSayeioKTtx7w',
#  'UCzm5zXJyyB0Vdh2fhi6jGmg',
#  'UCzm5QwutambV40cDjvlOovA',
#  'UCzm4LYzpoFMfg8HnUIz6xng',
#  'UCzm1ohiC0R5WbgVcYyXiYvw',
#  'UCzm1P18seSQmw97m5FmIh8Q',
#  'UCzm-oUXkrbRgS9BeIxqDqTg',
#  'UCzm-X8tDtEyrOeYiC9SdcJg',
#  'UCzlzvdG20hxefDCUMzA5afg',
#  'UCzlzd-W9QnHySOZ4fckELKA',
#  'UCzlz5cYL1KtF8CI5Y20maIQ',
#  'UCzlyk5J-8re9qSoOpfoPC5w',
#  'UCzlxS0qwetLblfUgYTrnt7Q',
#  'UCzlu25GM2wm3uz-In0rVeGQ',
#  'UCzlt8PEErHGi-OokYIX_UKA',
#  'UCzlsvmR4qC-ef36KAnltsyA',
#  'UCzls5gJTxnJI1uOyXdZm1Gg',
#  'UCzlpzD-FM9WezVkZHFM9TfQ',
#  'UCzlnaIrdxwJITyrESOReqxg',
#  'UCzllztCuniR_83Fwuz70xcg',
#  'UCzlfx6bYOkfJC0T6YjT5pXg',
#  'UCzlezC1TlnHaayCmTMB7yuA',
#  'UCzlccCLQpaOwRsyExX4D8bg',
#  'UCzlbq0niLXb3fkOBhG0vPaA',
#  'UCzl_RVz8LiWC955z79krvkQ',
#  'UCzl_J2mHdWN3muh8N-EWQVA',
#  'UCzlZsobxK2xbjsbzxd69lqQ',
#  'UCzlZYhwwaIGZABqaEffGj-g',
#  'UCzlYJ_wt56i98OFlX6vxWFA',
#  'UCzlXwR8hC2cY2r_TbME3ORw',
#  'UCzlXjOQ8y30mQ5SPRe6crtQ',
#  'UCzlXf-yUIaOpOjEjPrOO9TA',
#  'UCzlVX-v_r_Y1--xhV-m_W3Q',
#  'UCzlVPo9N4GWpCe2Lcp3QTRQ',
#  'UCzlV9dVDxDN4eJ6BpKKjsMQ',
#  'UCzlV2EqbIJJCgMbRGUU0sog',
#  'UCzlTGvOsTFGzIdWL4B8fkRg',
#  'UCzlQIrXfh82GnhmfolSer-w',
#  'UCzlQ9ES6rzAYVxgBRCwfxlw',
#  'UCzlMsy46uESj-SKro7oFYJw',
#  'UCzlLzpDBQs6Z5s69MNSRKVA',
#  'UCzlLlSDDqSlZAfxBzbfnXmg',
#  'UCzlKH5vnjm_DkIF5P7osrrQ',
#  'UCzlK88dpMLqi3bFdSEHK3-A',
#  'UCzlJYvF2dMVyK4LHf-8IOmw',
#  'UCzlJBcHZ9gj1sjuI2M6tsZw',
#  'UCzlIDC6RIY4eCI7NafyKXkg',
#  'UCzlH_BmLwKU8XDOe2TvKakg',
#  'UCzlHWDuIsOYutvXdCzvIBLw',
#  'UCzlH-Ah1a9NNYH6f9xUau9w',
#  'UCzlGEFvd9_Clle0HY0KoM-Q',
#  'UCzlDoBSiNbyHOq-lVXckVhA',
#  'UCzl8GEjZbjgtVj0ppupdBbg',
#  'UCzl7UIxD4bnFr3k3Qf1EgJw',
#  'UCzl7Nkka3BlN1tqnyvwAmSg',
#  'UCzl54RQebnO4Ymfahi_eadQ',
#  'UCzl0j9zQzn5PI1WlclZKzMg',
#  'UCzkzQUNfpg5da2kb6Sx1IRg',
#  'UCzkvhGgnyQ3apRX_PUIR5jw',
#  'UCzkqlPxdZhQS_OuIlRr097w',
#  'UCzkqOdzxj4wY7BmWdXWueoA',
#  'UCzkoEP3BkT5kQ4PURI09oaA',
#  'UCzklhIKdfHpFAGB8Vf8JXsg',
#  'UCzklZx1kdXuwsLYELVb55sQ',
#  'UCzklKRfaPGaJWGvRdtYe60Q',
#  'UCzkkfLiHY_9GQHT2fJ6ujwg',
#  'UCzkh4WFtAS3YhseITT5goeA',
#  'UCzkg2V5lfGU46g-SZ1KPVJQ',
#  'UCzkfrrjY9wqwC4EoKqRlgMQ',
#  'UCzkfkq385PdkI3CTfC0kgBA',
#  'UCzkeNiq57_lBnzpR-qX8Ttw',
#  'UCzkeEAwxes8jkbhJl7srptQ',
#  'UCzkd7PX5rLhPIfggTyhOIhg',
#  'UCzkcuUgsMln4y_aSxhE0H-g',
#  'UCzkaQrI9-nSv373EvK5p0SQ',
#  'UCzka7DjsnBgDBFFbRxsN_4A',
#  'UCzkYFFKmQL07dc-29Es04Vw',
#  'UCzkY7wa8Ksxv4M5NyUYgTmA',
#  'UCzkY0h7rwQjAlNW1NIz4H4g',
#  'UCzkWSx21Zhkg1lQ3lu0MmKA',
#  'UCzkSXAHDh2IdW6ZWK3FGqPQ',
#  'UCzkQUn3dly1pllin6jqK5Ng',
#  'UCzkPw7u2bYoS8aRfrukdPTw',
#  'UCzkPX3KCIVquUPa8oXjHn0g',
#  'UCzkPWzzhGXahUQ8FVLNwlHA',
#  'UCzkMbYgQgw0ADzsa9gejQQw',
#  'UCzkIxyihoqlCgFz9H5IrbPQ',
#  'UCzkIWCM6QNtK6CtgEIfBtAQ',
#  'UCzkHbTcw-XzH9R8qc7FBXJQ',
#  'UCzkFu0AVOtXy-vTo028mJxw',
#  'UCzkFCRiMcOBeef8xcaqipmw',
#  'UCzkE0YBibtsjimBs8tsbRxg',
#  'UCzkBy1ftt7KG-XvjkAjkFjw',
#  'UCzk7U04qVe4SJOniGBPMcHA',
#  'UCzk7S5fziTaYj57p49-Q1Sg',
#  'UCzk6NKUNQp_Dh0MqT6qWvWw',
#  'UCzk4rpMHgNLMv9Dg3k5QxFQ',
#  'UCzk3xzWEoMji53dyHGEWGeA',
#  'UCzk3niQ1yD_nlfMqWZ1MI3Q',
#  'UCzk3SGbBNQjPbnihyYnFNJA',
#  'UCzk1ynFizYGUYs_89yj6WEQ',
#  'UCzk0mdDVDMqAJP4_pzTy9Tw',
#  'UCzk0m5Ibzv-JDJHRrNNbGyw',
#  'UCzk08fzh5c_BhjQa1w35wtA',
#  'UCzjzpGhjupwJjA-Rnu4zjMg',
#  'UCzjyMXv0jg1RBg1PAdYmHsQ',
#  'UCzjqt3OxiwxhLduf4kidBRg',
#  'UCzjncYsUc4PZpVaCJpnVysg',
#  'UCzjmB_ScmzQBJf7r-nCFOAw',
#  'UCzjilapfIua3Ahmc68CTtIA',
#  'UCzjhPVEfz-z6xJ28_1Squ1g',
#  'UCzjeYdI145S8VzGFsODpXoA',
#  'UCzjc5u-yPodS9U9E4tpNRUw',
#  'UCzjYSapwqiQXvVWo03JLtcg',
#  'UCzjVzXft4T_iORQtY4El39w',
#  'UCzjTgl6nhliuJeTqeRO9crQ',
#  'UCzjSy7WfBx6aAFIH4st8C0w',
#  'UCzjQHubuI2z95VCTESuUl2A',
#  'UCzjKFGxAQKNsydtyJMRLeEA',
#  'UCzjJwaeSBEzBm3qzjNW7sQA',
#  'UCzjJadbFW7eIq0HEiFjdD6w',
#  'UCzjILZxaqNI0FM_XPPkcRJw',
#  'UCzjH9cH-yqrfOD82khfOelQ',
#  'UCzjGv0ghEbFanUQ9ZF5A9-g',
#  'UCzjEaNu4XLpX6I8nyE_cQZA',
#  'UCzjCfV3LHyarKbdb-2ScGZg',
#  'UCzjAjd9TbVyvmB9ssXV_lzQ',
#  'UCzj5pofLaoZmp4ILL9dg4dA',
#  'UCzj5G1iVtzurfctuTwU07ig',
#  'UCzj4_kzn-3qq2OSSjR5qI7g',
#  'UCzj41PvS6wpzs4JkXTY0ikA',
#  'UCzj25NxFjI5jJM8StIBOvPA',
#  'UCzj1Xm2QcJ9Imq97cQzJa0w',
#  'UCzj0c1rWIlv9odxr7HKMiAQ',
#  'UCziz6FiCnkyQ810X7qXFMZw',
#  'UCziyNYy86jS1t9GAzupmWqw',
#  'UCzixfFiEFMjhSB3R9UdUdsA',
#  'UCziwLfSSPLWc8bp02Pc5azg',
#  'UCzirj3jHFdxAqOnPxDAxQ_Q',
#  'UCziqiPwRyU4QnkwAeg-nTZA',
#  'UCziq_vt-SLT9Pk4MJmVAaJA',
#  'UCziolmvFYFINWWde2a7Z_1Q',
#  'UCziohsHRLBRvbqEp-itVj4g',
#  'UCzio43cv-Ib4a-llFGy_pbQ',
#  'UCzintVBt4NqmWM_OxNDlk_w',
#  'UCzikD34vRLAcUlASQnleBnQ',
#  'UCzih5SV69WsTAlCzlyOs-YQ',
#  'UCzigp9Uguz22sGUQ1QGHN8Q',
#  'UCzig_-A_lckYeMs6FTbbMPQ',
#  'UCzifY2lrFoSPcj9mcbzE-ug',
#  'UCzieLnaSIshZsC-TUePvXRQ',
#  'UCzidYiSzphWZEF3l5hMxKvg',
#  'UCzicvxX--jNZcXMIP7Pga7Q']

# %% [markdown]
# # Youtube Channel Diversity

# %% [markdown]
# To study the impact for diversity on performances we need to find a measurement of diversity.
#
# **First idea** : we can do a simple count for the number different categories among the videos of the channel.
#
# **Second idea** : we can do a simple count but with a treshold, only count the categories that reprensent a certain percentage of the total videos of the channel.
#
# **Third idea** : create a weighted count. the idea behind it is that the more a channel have different video categories and the more those categories a evenly distributed the higher the score will be. (we case use entropie formula).

# %%
# Time complexity : O(number of rows) 
def get_video_category_distribution_dict(data, category_list):
    """
    Function that returns the dictionnary that associate each channel_id with
    the dictionnary that count the number of videos in each category

    {'channel_id1' : {'cat1': n1, ..., 'catK' : nK}, 'channel_id2' : ... }

    Parameters:
    data : the dataset of videos.
    category_list : the list of categories, can be easily computer with another dataset.

    Returns:
    dict: the built dictionnary.
    """

    # Dict Init
    channel_id_list = get_unique_values(data, 'channel_id')
    dict = {channel_id : {category : 0 for category in category_list} for channel_id in channel_id_list}

    for i in range(len(data)):
        channel_id = data.iloc[i]['channel_id']
        category = data.iloc[i]['categories']
        dict[channel_id][category] += 1

    return dict

# %%
'''it might be usefull to use a global variable for category_list, because
with the reel dataset it can be costly to get it with get_unique_values'''

categories_list = get_unique_values(df, 'categories')
dict = get_video_category_distribution_dict(df, categories_list)

# %%
dict['UCzzfu83LhPMMuhtDVA75rfw']
# Out:
# {'Entertainment': 12,
#  'Gaming': 0,
#  'Howto & Style': 30,
#  'Travel & Events': 96,
#  'People & Blogs': 10,
#  'Music': 0,
#  'Science & Technology': 0,
#  'Film & Animation': 1,
#  'Comedy': 0,
#  'Education': 0,
#  'Autos & Vehicles': 140,
#  'Pets & Animals': 8,
#  'Sports': 0,
#  'News & Politics': 0,
#  'Nonprofits & Activism': 0}

# %% [markdown]
#  **Let's see if YouTubers are already covering multiple categories in their content.**

# %%
def youtube_statistics_by_categories(youtube_dict, is_plot=False):
    print(len(youtube_dict))
    youtubers_non_principal_category_percentages = []
    youtubers_above_20_percent = 0  
    youtubers_above_20_percent_dict = {}  

    for youtuber, categories in youtube_dict.items():
        total_videos = sum(categories.values())
        if total_videos > 0:
            first_category_videos = max(categories.values())
            non_principal_category_videos = total_videos - first_category_videos
            percentage_in_non_principal_categories = (non_principal_category_videos / total_videos) * 100
            youtubers_non_principal_category_percentages.append(percentage_in_non_principal_categories)
            
            if percentage_in_non_principal_categories >= 20:
                youtubers_above_20_percent += 1
                youtubers_above_20_percent_dict[youtuber] = categories  # Ajouter au dictionnaire
    if is_plot:
        plt.figure(figsize=(8, 6))
        sns.histplot(youtubers_non_principal_category_percentages, kde=False, bins=range(0, 101, 5), color='teal')
        plt.axvline(20, color='red', linestyle='--', label='20% in non-principal categories')
        plt.title('Percentage of content in non-principal categories by YouTuber')
        plt.xlabel('Percentage of content in non-principal categories')
        plt.ylabel('Number of YouTubers')
        plt.legend()
        plt.show()

        print(f"Number of YouTubers with at least 20% of content in non-principal categories: {youtubers_above_20_percent}")
    
    return youtubers_above_20_percent_dict

filtered_youtube_dict = youtube_statistics_by_categories(dict, True)
# Out:
# 758
# C:\Users\redou\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Number of YouTubers with at least 20% of content in non-principal categories: 191

# %% [markdown]
# The majority of YouTubers do not diversify their channels, with only 24% of YouTubers having at least 20% of videos in categories different from their main one.

# %% [markdown]
# **Let's define a metric of diversity score**

# %%
def get_basic_diversity_score(video_category_distribution_dict, channel_id):
    score = 0

    for value in video_category_distribution_dict[channel_id].values():
        if value > 0:
            score += 1

    return score

# %%
def get_threshold_diversity_score(video_category_distribution_dict, channel_id, treshold):

    video_cat_dist = video_category_distribution_dict[channel_id]
    total_video_number = sum([value for value in video_cat_dist.values()])

    score = 0

    for value in video_cat_dist.values():
        if (value > int(total_video_number * treshold)):
            score += 1

    return score

# %% [markdown]
# **Weighted Score : Normalized Entropy**
#
# $C$ is the number of caterories
# , $p_i$ the proportion of videos that are in the category $i$.
#
#
# $$Score(p_1, ...,p_C) = - \frac{\sum _{i}^{C} p_i log (p_i)}{log(C)}$$

# %%
def get_weighted_diversity_score(video_category_distribution_dict, channel_id):

    video_cat_dist = video_category_distribution_dict[channel_id]
    total_video_number = sum([value for value in video_cat_dist.values()])

    C = len(video_cat_dist)
    score = 0

    for value in video_cat_dist.values():
        p = value/total_video_number
        if p != 0:
            score = score + (p * np.log(p)) # to avoid log(0)
        
    return - score / np.log(C)

# %%
print('Diversity score using entropy formula :',get_weighted_diversity_score(dict, channel_id = 'UCzzzrOhp92PkGrIwGH3_EEg').round(3))
# Out:
# Diversity score using entropy formula : 0.172

# %%
def plot_channel_videos_distribution(video_category_distribution_dict, channel_id):

    # Convert the value into proportions
    data = video_category_distribution_dict[channel_id].copy()
    total_video_number = sum([value for value in data.values()])
    for cat in data.keys():
        data[cat] = data[cat] / total_video_number
        
    df = pd.DataFrame(list(data.items()), columns=['Category', 'Video Count'])
    score = get_weighted_diversity_score(video_category_distribution_dict, channel_id)

    plt.figure(figsize=(10, 6))
    sns.barplot(y='Category', x='Video Count', data=df, palette='viridis')
    
    plt.xticks(rotation=90)
    plt.title(f'Proportion of videos in each category - {channel_id} - Score : {score.round(3)}')
    plt.xlabel('Percentage')
    plt.xticks(rotation=0)
    plt.ylabel('')
    plt.tight_layout()
    plt.grid(alpha=0.3)
    plt.show()

plot_channel_videos_distribution(dict, 'UCzzzPMh9fZHxc7gxPRB2LHQ')

# %%
plot_channel_videos_distribution(dict, 'UCzzfu83LhPMMuhtDVA75rfw')

# %% [markdown]
# # Distances between youtube channels categories

# %% [markdown]
# we can define a **link strength** between categories.
#
# **First idea** : we can define the link strength between cat1 and cat2 by the number of time a channel has already create one video of each category
#
# to compute this link strength, we can create a dictionnary, dict['Gaming']['Entertainment'] = link strength between 'Gaming' and 'Entertainment'

# %%
def get_link_strength_dict(data, video_category_distribution_dict, categories_list):

    link_strength_dict = {category : {category : 0 for category in categories_list} for category in categories_list}

    channels_id_list = get_unique_values(data, 'channel_id')

    for cat_dist in video_category_distribution_dict.values():
        for cat1 in categories_list:
            for cat2 in categories_list:
                if cat_dist[cat1] and cat_dist[cat2]:
                    link_strength_dict[cat1][cat2] += 1

    return link_strength_dict

# %%
def display_link_strength(data, video_category_distribution_dict, category_list):

    link_strength_dict = get_link_strength_dict(data, video_category_distribution_dict, category_list)
    df = pd.DataFrame(link_strength_dict).astype(int)

    return df

# %%
display_link_strength(df, dict, categories_list)
# Out:
#                        Entertainment  Gaming  Howto & Style  Travel & Events  \
# Entertainment                    319      73             84               57
# Gaming                            73     162             26               22
# Howto & Style                     84      26            158               43
# Travel & Events                   57      22             43               78
# People & Blogs                   189      68            105               59
# Music                            116      29             42               22
# Science & Technology              51      24             46               23
# Film & Animation                 105      43             55               35
# Comedy                            94      36             44               38
# Education                         82      33             48               38
# Autos & Vehicles                  32      20             23               22
# Pets & Animals                    36      12             30               27
# Sports                            57      24             28               31
# News & Politics                   48      17             25               24
# Nonprofits & Activism             29      11             19               14
#
#                        People & Blogs  Music  Science & Technology  \
# Entertainment                     189    116                    51
# Gaming                             68     29                    24
# Howto & Style                     105     42                    46
# Travel & Events                    59     22                    23
# People & Blogs                    368    106                    60
# Music                             106    279                    24
# Science & Technology               60     24                    93
# Film & Animation                  107     53                    37
# Comedy                             79     49                    26
# Education                          83     42                    49
# Autos & Vehicles                   39     15                    25
# Pets & Animals                     39     20                    19
# Sports                             55     33                    24
# News & Politics                    48     29                    25
# Nonprofits & Activism              31     19                    19
#
#                        Film & Animation  Comedy  Education  Autos & Vehicles  \
# Entertainment                       105      94         82                32
# Gaming                               43      36         33                20
# Howto & Style                        55      44         48                23
# Travel & Events                      35      38         38                22
# People & Blogs                      107      79         83                39
# Music                                53      49         42                15
# Science & Technology                 37      26         49                25
# Film & Animation                    169      54         54                21
# Comedy                               54     117         41                18
# Education                            54      41        132                21
# Autos & Vehicles                     21      18         21                59
# Pets & Animals                       22      27         26                18
# Sports                               33      31         33                23
# News & Politics                      32      28         37                14
# Nonprofits & Activism                22      22         25                 7
#
#                        Pets & Animals  Sports  News & Politics  \
# Entertainment                      36      57               48
# Gaming                             12      24               17
# Howto & Style                      30      28               25
# Travel & Events                    27      31               24
# People & Blogs                     39      55               48
# Music                              20      33               29
# Science & Technology               19      24               25
# Film & Animation                   22      33               32
# Comedy                             27      31               28
# Education                          26      33               37
# Autos & Vehicles                   18      23               14
# Pets & Animals                     49      20               16
# Sports                             20      82               21
# News & Politics                    16      21               63
# Nonprofits & Activism              11      13               24
#
#                        Nonprofits & Activism
# Entertainment                             29
# Gaming                                    11
# Howto & Style                             19
# Travel & Events                           14
# People & Blogs                            31
# Music                                     19
# Science & Technology                      19
# Film & Animation                          22
# Comedy                                    22
# Education                                 25
# Autos & Vehicles                           7
# Pets & Animals                            11
# Sports                                    13
# News & Politics                           24
# Nonprofits & Activism                     42

# %% [markdown]
# **Two ideas to compute the distance between categories**
#
# $A_i$ and $B_i$ are the frequencies of categories $A$ and $B$ in channel $i$
#
# $$\text{Cosine Similarity}(A, B) = \frac{\sum_{i=1}^{C} A_i \cdot B_i}{\sqrt{\sum_{i=1}^{C} A_i^2} \cdot \sqrt{\sum_{i=1}^{C} B_i^2}}$$
#
# $S_A$ is the set of channels where category $A$ appears,
# $S_B$ is the set of channels where category $B$ appears,
#
# $|S_A \cap S_B|$  is the size of the intersection of the sets $S_A$ and $S_B$,
#
# $|S_A \cup S_B|$  is the size of the union of the sets $S_A$ and $S_B$,
#
# $$\text{Jaccard Similarity}(A, B) = \frac{|S_A \cap S_B|}{|S_A \cup S_B|}$$

# %%
def jaccard_similarity(cat1, cat2, video_category_distribution_dict):

    intersection = 0
    union = 0

    for dict in video_category_distribution_dict.values():
        if dict[cat1] and dict[cat2]:
            intersection+=1
        if dict[cat1] or dict[cat2]:
            union+=1

    return intersection/union

# %%
def cosine_similarity(cat1, cat2, video_category_distribution_dict):

    result, n1, n2 = 0, 0, 0

    for dict in video_category_distribution_dict.values():
        result += dict[cat1]*dict[cat2]
        n1 += dict[cat1]**2
        n2 += dict[cat2]**2

    return result / (np.sqrt(n1) * np.sqrt(n2))

# %%
def compute_distance(cat1, cat2, video_category_distribution_dict):

    for dict in video_category_distribution_dict.values():
        if dict[cat2] == 0:
            return 0
        else:
            return 1-1/dict[cat2]

# %%
cosine_similarity('Music', 'Entertainment', dict)
# Out:
# 0.05767879791686198

# %%
jaccard_similarity('Music', 'Entertainment', dict)
# Out:
# 0.24066390041493776

# %%
def display_similarity(data, video_category_distribution_dict, categories_list, similarity_function):
    similarity_dict = {cat : {cat : 0 for cat in categories_list} for cat in categories_list}
    for cat1 in categories_list:
        for cat2 in categories_list:
            similarity_dict[cat1][cat2] = similarity_function(cat1, cat2, video_category_distribution_dict)
        
    df = pd.DataFrame(similarity_dict)

    return df

# %%
def plot_heatmap(df):
    # Créer la heatmap avec Seaborn
    plt.figure(figsize=(10, 8))
    sns.heatmap(df, annot=True, cmap='Blues', fmt=".2f", linewidths=0.5, cbar_kws={'label': 'Similarity'})
    plt.title('Category Similarity Heatmap')
    plt.show()

# %%
plot_heatmap(display_similarity(df, dict, categories_list, jaccard_similarity))

# %%
plot_heatmap(display_similarity(df, dict, categories_list, cosine_similarity))

# %% [markdown]
# **Problem**: We want to identify YouTube video categories that often appear together on creators' channels. However, the metrics we’re currently using face challenges in accurately capturing this, partly due to noise from small numbers of videos and differences in how categories are distributed. Here are two specific limitations:
#
# Jaccard Similarity: This metric doesn’t effectively distinguish between channels that focus mainly on one category versus those with a more balanced mix. For example, a channel with 49 "gaming" videos and just 1 "sports" video would have the same Jaccard similarity between "gaming" and "sports" as a channel with 25 "gaming" and 25 "sports" videos, since Jaccard only considers whether each category is present or not. This makes it hard to capture the real connection between categories.
#
# Cosine Similarity: This metric is also insensitive to differences in video counts between categories. For example, a channel with 50 "gaming" and 50 "music" videos could show the same cosine similarity between "gaming" and "music" as a channel with just 1 video in each category. This focus on relative proportions, instead of the actual counts, makes it harder to measure how strongly categories are paired.

# %% [markdown]
# **Solutions**:

# %% [markdown]
# To fix Jaccard Similarity problem, we can define :
# Weighted Jaccard Similarity as following
# $$
# \text{Weighted Jaccard Similarity}(A, B) = \frac{\sum_i \min(A_i, B_i)}{\sum_i \max(A_i, B_i)}
# $$
#
# where $A_i$ and $B_i$ represents the numbers of occurences of category $A$ and $B$ for the channel $i$.

# %%
def weighted_jaccard_similarity(cat1, cat2, video_category_distribution_dict):

    intersection_sum = 0
    union_sum = 0
    
    for counts in video_category_distribution_dict.values():
        count_cat1 = counts.get(cat1, 0)
        count_cat2 = counts.get(cat2, 0)

        intersection_sum += min(count_cat1, count_cat2)
        union_sum += max(count_cat1, count_cat2)
    
    if union_sum == 0:
        return 0
    
    return intersection_sum / union_sum

# %%
plot_heatmap(display_similarity(df, dict, categories_list, weighted_jaccard_similarity))

# %% [markdown]
# To fix the issue of noise caused by categories with few occurrences, we can filter out these categories by setting a threshold based on the percentage of a category's presence in a channel before it is considered.

# %%
def filter_categories_by_threshold(dico, threshold=0.1):

    for channel, category_data in dico.items():
        total_videos = sum(category_data.values())  
        if total_videos == 0:
            continue  
        

        for category, count in category_data.items():
            proportion = count / total_videos 
            if proportion < threshold:
                category_data[category] = 0  
                
    return dico

# %%
dict2 = copy.deepcopy(dict) 
dict2['UCzzfu83LhPMMuhtDVA75rfw']
# Out:
# {'Entertainment': 12,
#  'Gaming': 0,
#  'Howto & Style': 30,
#  'Travel & Events': 96,
#  'People & Blogs': 10,
#  'Music': 0,
#  'Science & Technology': 0,
#  'Film & Animation': 1,
#  'Comedy': 0,
#  'Education': 0,
#  'Autos & Vehicles': 140,
#  'Pets & Animals': 8,
#  'Sports': 0,
#  'News & Politics': 0,
#  'Nonprofits & Activism': 0}

# %%
dict2 = filter_categories_by_threshold(dict2)
dict2['UCzzfu83LhPMMuhtDVA75rfw']
# Out:
# {'Entertainment': 0,
#  'Gaming': 0,
#  'Howto & Style': 30,
#  'Travel & Events': 96,
#  'People & Blogs': 0,
#  'Music': 0,
#  'Science & Technology': 0,
#  'Film & Animation': 0,
#  'Comedy': 0,
#  'Education': 0,
#  'Autos & Vehicles': 140,
#  'Pets & Animals': 0,
#  'Sports': 0,
#  'News & Politics': 0,
#  'Nonprofits & Activism': 0}

# %%
plot_heatmap(display_similarity(df, dict2, categories_list, jaccard_similarity))

# %%
plot_heatmap(display_similarity(df, dict2, categories_list, cosine_similarity))

# %% [markdown]
# ## Correlation avec le nombre d'abonnés, vues & graphe sur la diversité

# %%
dict3 = youtube_statistics_by_categories(dict)
# Out:
# 758

# %%
dict3
# Out:
# {'UCzzzZ3-icktxbC3j7hkWqRw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 30,
#   'Travel & Events': 9,
#   'People & Blogs': 4,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzzPMh9fZHxc7gxPRB2LHQ': {'Entertainment': 922,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 705,
#   'Music': 1,
#   'Science & Technology': 16,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzuPi9S7NNCdkiHAcx92Qg': {'Entertainment': 63,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 17,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 3,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzztaOtjmaZoiLvWLagq7bg': {'Entertainment': 233,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 65,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzmGsmy8cBxmqljbVG_e7Q': {'Entertainment': 54,
#   'Gaming': 0,
#   'Howto & Style': 6,
#   'Travel & Events': 0,
#   'People & Blogs': 164,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzfu83LhPMMuhtDVA75rfw': {'Entertainment': 12,
#   'Gaming': 0,
#   'Howto & Style': 30,
#   'Travel & Events': 96,
#   'People & Blogs': 10,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 140,
#   'Pets & Animals': 8,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzeO6b8v8bBt7gjSWBKzOg': {'Entertainment': 70,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 13,
#   'Music': 119,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzUx3uOjiRM-FsBH027O9w': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 12,
#   'Music': 37,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzT17GEeEPojZe7FT7skag': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 141,
#   'Travel & Events': 86,
#   'People & Blogs': 4,
#   'Music': 0,
#   'Science & Technology': 1,
#   'Film & Animation': 7,
#   'Comedy': 0,
#   'Education': 4,
#   'Autos & Vehicles': 1,
#   'Pets & Animals': 2,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzSPRyMYUw6IGueHr1K0Jg': {'Entertainment': 83,
#   'Gaming': 409,
#   'Howto & Style': 0,
#   'Travel & Events': 2,
#   'People & Blogs': 11,
#   'Music': 0,
#   'Science & Technology': 1,
#   'Film & Animation': 2,
#   'Comedy': 10,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzQnR2e5VIgziK3SiJ6uIg': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 640,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 304},
#  'UCzzN0bL-q5EfdolAwiiBDhA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 2,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 36,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 11,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzD5Pq4JHseXnZQzbBkcOA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 304,
#   'Travel & Events': 0,
#   'People & Blogs': 128,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 154,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 1,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzzD3izXihYOewbthyFb2pw': {'Entertainment': 0,
#   'Gaming': 2,
#   'Howto & Style': 17,
#   'Travel & Events': 246,
#   'People & Blogs': 25,
#   'Music': 0,
#   'Science & Technology': 5,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 36,
#   'Autos & Vehicles': 36,
#   'Pets & Animals': 27,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 0},
#  'UCzz6z566lJPtjqKOPUmHZKQ': {'Entertainment': 8,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 4,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 37,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 1,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 5},
#  'UCzz6OY86r6OJmVvI_H9Q1RQ': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 116,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 32,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzyxWsAmXccLSFO4DLVoxGg': {'Entertainment': 7,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 41,
#   'People & Blogs': 0,
#   'Music': 1,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 25,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzyuszXJUbY6w-S_t3n7hNQ': {'Entertainment': 206,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 121,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 1,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 0},
#  'UCzyuclWm7yANjLYP4vlcleg': {'Entertainment': 24,
#   'Gaming': 0,
#   'Howto & Style': 108,
#   'Travel & Events': 1,
#   'People & Blogs': 5,
#   'Music': 556,
#   'Science & Technology': 103,
#   'Film & Animation': 451,
#   'Comedy': 0,
#   'Education': 2,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 7,
#   'Nonprofits & Activism': 0},
#  'UCzysEHp6XaSBji4FEjYn1LQ': {'Entertainment': 97,
#   'Gaming': 5,
#   'Howto & Style': 1,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 26,
#   'Science & Technology': 1,
#   'Film & Animation': 55,
#   'Comedy': 86,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzyrNGiPTivg4sxUrRRmbCg': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 55,
#   'Travel & Events': 0,
#   'People & Blogs': 13,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 16,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzyk5gg98nCQ5j-YSKr-w5A': {'Entertainment': 0,
#   'Gaming': 5,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 13,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 1,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzyjTSS_L1ttmOq-Zqc_Mrw': {'Entertainment': 43,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 17,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 13,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzybXLxv08IApdjdN0mJhEg': {'Entertainment': 23,
#   'Gaming': 21,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 5,
#   'Music': 1,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 0},
#  'UCzyR6O1o5fjdwvmKOaMOBaQ': {'Entertainment': 1,
#   'Gaming': 0,
#   'Howto & Style': 2,
#   'Travel & Events': 0,
#   'People & Blogs': 70,
#   'Music': 200,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzxztcLww-jPvE5QbFC3n0g': {'Entertainment': 394,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 7,
#   'People & Blogs': 19,
#   'Music': 0,
#   'Science & Technology': 1,
#   'Film & Animation': 6,
#   'Comedy': 1,
#   'Education': 7,
#   'Autos & Vehicles': 168,
#   'Pets & Animals': 4,
#   'Sports': 0,
#   'News & Politics': 304,
#   'Nonprofits & Activism': 1},
#  'UCzxeUZZFIhMtoYRwspfic4A': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 7,
#   'Music': 10,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzxWtRVuke4GnD6JWQ72U4A': {'Entertainment': 98,
#   'Gaming': 0,
#   'Howto & Style': 28,
#   'Travel & Events': 1,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzxTzOeoy-DQG_3IVwnOo5A': {'Entertainment': 195,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 36,
#   'People & Blogs': 16,
#   'Music': 25,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 23,
#   'Education': 5,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 5},
#  'UCzxR9hrjzqZVq7imo_y37-A': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 91,
#   'Travel & Events': 0,
#   'People & Blogs': 25,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzxLOMj3HTM4yKGNtaG34-Q': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 11,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 107,
#   'Film & Animation': 28,
#   'Comedy': 49,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzxDOqKrg3sHcatf-7URUMw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 49,
#   'Travel & Events': 0,
#   'People & Blogs': 59,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzx9exbj1Zoh51o2Sr5rxBQ': {'Entertainment': 21,
#   'Gaming': 21,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzx1ee7FllS2YBaobO5YZmg': {'Entertainment': 0,
#   'Gaming': 483,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 7,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 222,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzx-2x9xINGUNhOGqGqzvIg': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 29,
#   'Music': 27,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwyWaqF9ofIUy4EU41GZiQ': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 14,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 6,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 38,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwwBSRb4pYlJ4DIVh_Am2A': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 12,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 3,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwvRsqiMdBdf1jjePraHxg': {'Entertainment': 221,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 61,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 3,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 0},
#  'UCzwozfj5iRDcKl032IhjGUw': {'Entertainment': 25,
#   'Gaming': 0,
#   'Howto & Style': 8,
#   'Travel & Events': 0,
#   'People & Blogs': 59,
#   'Music': 0,
#   'Science & Technology': 11,
#   'Film & Animation': 0,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwnUEmVsMOrtR2rlLkNnSQ': {'Entertainment': 242,
#   'Gaming': 0,
#   'Howto & Style': 315,
#   'Travel & Events': 0,
#   'People & Blogs': 52,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 0,
#   'Education': 52,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwlnJ_NUsmin7DtPRDNCHg': {'Entertainment': 23,
#   'Gaming': 0,
#   'Howto & Style': 9,
#   'Travel & Events': 2,
#   'People & Blogs': 19,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 2,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 2,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwl3WOpGBUoy6bbyV9Bpyg': {'Entertainment': 7,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 57,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 177,
#   'Pets & Animals': 0,
#   'Sports': 38,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwkdb9w47TR2pY99GwXf1Q': {'Entertainment': 12,
#   'Gaming': 0,
#   'Howto & Style': 185,
#   'Travel & Events': 92,
#   'People & Blogs': 202,
#   'Music': 0,
#   'Science & Technology': 29,
#   'Film & Animation': 5,
#   'Comedy': 8,
#   'Education': 2,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 7,
#   'News & Politics': 6,
#   'Nonprofits & Activism': 0},
#  'UCzwKe9jWNVr-C2TbtoxfHqQ': {'Entertainment': 13,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 3,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzwFZOhCfCZTgLruMz_RWCw': {'Entertainment': 22,
#   'Gaming': 15,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 2,
#   'Film & Animation': 0,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzw93BqU8XR8H55pNeQXVjw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 24,
#   'Music': 0,
#   'Science & Technology': 51,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 5,
#   'Autos & Vehicles': 5,
#   'Pets & Animals': 1,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 15},
#  'UCzvriNT36xQ9XZ_bEZ7XPjw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 35,
#   'Travel & Events': 0,
#   'People & Blogs': 39,
#   'Music': 0,
#   'Science & Technology': 26,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzvleCgTB-wNHtmN7he-hqg': {'Entertainment': 292,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 660,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 311,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzvl_gwH082JS1QFyL00gEA': {'Entertainment': 119,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 37,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzvdhZxx0IXwIuFltpHoi0w': {'Entertainment': 15,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 30,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 4,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzvd3SYAZEeDvRweVKa-YDQ': {'Entertainment': 618,
#   'Gaming': 2,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 920,
#   'Music': 11,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 86,
#   'Nonprofits & Activism': 0},
#  'UCzvJMUdiq83refanctkG9IA': {'Entertainment': 21,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 20,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 14,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzv1t7voB-bxMmXLysT4h0w': {'Entertainment': 0,
#   'Gaming': 438,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 16,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 149,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzusrs6aDzKs9mfAWf9SG9g': {'Entertainment': 4,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 3,
#   'Comedy': 6,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuolFXlT-MX-FCwXz9x5HQ': {'Entertainment': 1055,
#   'Gaming': 823,
#   'Howto & Style': 0,
#   'Travel & Events': 84,
#   'People & Blogs': 41,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuhnV9yUolL8Evdd_nhAaA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 10,
#   'Music': 0,
#   'Science & Technology': 104,
#   'Film & Animation': 24,
#   'Comedy': 0,
#   'Education': 30,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 2,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuZWTVU97w9TUGpPQYfIeQ': {'Entertainment': 302,
#   'Gaming': 743,
#   'Howto & Style': 0,
#   'Travel & Events': 22,
#   'People & Blogs': 28,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 6,
#   'Comedy': 2,
#   'Education': 2,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 3,
#   'Nonprofits & Activism': 22},
#  'UCzuW84oOedCNL4gY7R4hR4w': {'Entertainment': 58,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 26,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuRLPegnu6m8HZ-qkWEF1Q': {'Entertainment': 2,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 12,
#   'Music': 49,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 10,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuLUZV3Y_X6cDz7SUpqrtw': {'Entertainment': 1,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 5,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 8,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 3,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuJendDw8ug_rVEI6oc8Kg': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 122,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 33,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuHs9vu5MswahKTT1iClFQ': {'Entertainment': 43,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 17,
#   'Music': 0,
#   'Science & Technology': 14,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 190,
#   'Autos & Vehicles': 5,
#   'Pets & Animals': 5,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuFRkWj9156yqVO8eat0LA': {'Entertainment': 5,
#   'Gaming': 12,
#   'Howto & Style': 6,
#   'Travel & Events': 58,
#   'People & Blogs': 18,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 15,
#   'Comedy': 4,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 179,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzuBLmu_0tCIuJW1mTWEqMw': {'Entertainment': 38,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 79,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCztp7FHZRT_tCBBoLVa1lSw': {'Entertainment': 48,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 46,
#   'Comedy': 0,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCztogSMGMu_EiJWwFbZIPBw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 7,
#   'Travel & Events': 0,
#   'People & Blogs': 9,
#   'Music': 74,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 37,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCztm-DxaKV1EpXSVxlVvbeg': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 53,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 80,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCztlt79t8cvrtLpnoIXz2Pg': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 4,
#   'Music': 11,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCztXZVQiVSqoDTC9USNPeqQ': {'Entertainment': 20,
#   'Gaming': 0,
#   'Howto & Style': 2,
#   'Travel & Events': 653,
#   'People & Blogs': 49,
#   'Music': 0,
#   'Science & Technology': 31,
#   'Film & Animation': 0,
#   'Comedy': 2,
#   'Education': 0,
#   'Autos & Vehicles': 101,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCztHdGwzRkxXlJe3Vxi11CQ': {'Entertainment': 16,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 3,
#   'People & Blogs': 22,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 29,
#   'Education': 0,
#   'Autos & Vehicles': 1,
#   'Pets & Animals': 0,
#   'Sports': 50,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 25},
#  'UCzt8j2oNWY29DD9TG9mhMmw': {'Entertainment': 5,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 34,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 4,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 69,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzt83aKE8MSqyLxxKfKVH8w': {'Entertainment': 7,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 9,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 4,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 7,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzt-FIYMtaequzIOtppv8NQ': {'Entertainment': 22,
#   'Gaming': 0,
#   'Howto & Style': 389,
#   'Travel & Events': 0,
#   'People & Blogs': 202,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 35,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzszIh4jH06kYp7k_DxhH5A': {'Entertainment': 350,
#   'Gaming': 0,
#   'Howto & Style': 11,
#   'Travel & Events': 0,
#   'People & Blogs': 72,
#   'Music': 66,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsvSXSk01GJc0QDUt7eYiA': {'Entertainment': 1135,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 0,
#   'People & Blogs': 2,
#   'Music': 75,
#   'Science & Technology': 0,
#   'Film & Animation': 208,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsqJV6eaQPlmaXgmYaw9kw': {'Entertainment': 447,
#   'Gaming': 107,
#   'Howto & Style': 1,
#   'Travel & Events': 0,
#   'People & Blogs': 71,
#   'Music': 20,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 174,
#   'Education': 4,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 881,
#   'News & Politics': 13,
#   'Nonprofits & Activism': 0},
#  'UCzso0nsdJHgbnjMI1rJpp6A': {'Entertainment': 2,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 12,
#   'Music': 12,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 56,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsjHlc0WRwZYwlinsmtM4w': {'Entertainment': 26,
#   'Gaming': 0,
#   'Howto & Style': 38,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 2,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsaQoeRJjnnaQrLWDZ071A': {'Entertainment': 0,
#   'Gaming': 1,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 8,
#   'Music': 3,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsRJHtbT5cG2lthJD3lQ6w': {'Entertainment': 8,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 18,
#   'Music': 15,
#   'Science & Technology': 0,
#   'Film & Animation': 7,
#   'Comedy': 6,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 1,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsR3ghNLC6qCQrHlAKlGVQ': {'Entertainment': 1,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 190,
#   'Music': 0,
#   'Science & Technology': 496,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 61,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsNQvqs01ShacBpieecFSQ': {'Entertainment': 33,
#   'Gaming': 0,
#   'Howto & Style': 7,
#   'Travel & Events': 0,
#   'People & Blogs': 44,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsMguDJtmra1sJl7yNhhWQ': {'Entertainment': 67,
#   'Gaming': 69,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 83,
#   'Comedy': 8,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsMKR_d_O1U-DNDhjWkkAg': {'Entertainment': 0,
#   'Gaming': 4,
#   'Howto & Style': 3,
#   'Travel & Events': 0,
#   'People & Blogs': 4,
#   'Music': 1,
#   'Science & Technology': 43,
#   'Film & Animation': 2,
#   'Comedy': 0,
#   'Education': 71,
#   'Autos & Vehicles': 1,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsJwVqrumDb2JziGh0-A6w': {'Entertainment': 62,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 249,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 5,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsEaoavFxLqwpNNBGhKLPw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 85,
#   'Travel & Events': 0,
#   'People & Blogs': 148,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 50,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzsBcdCIf7XrDzSft4774ZQ': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 51,
#   'Music': 4,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 141,
#   'Autos & Vehicles': 17,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzs8bEZtZR4RkV0stTydurg': {'Entertainment': 9,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 25,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzs7ZW1Car1DctJK3_Xo-2Q': {'Entertainment': 1,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 61,
#   'Music': 111,
#   'Science & Technology': 0,
#   'Film & Animation': 25,
#   'Comedy': 158,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzs6lOMCW6ZaLPoWQfzPBiQ': {'Entertainment': 6,
#   'Gaming': 1,
#   'Howto & Style': 3,
#   'Travel & Events': 8,
#   'People & Blogs': 0,
#   'Music': 260,
#   'Science & Technology': 1,
#   'Film & Animation': 0,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 10,
#   'Pets & Animals': 158,
#   'Sports': 33,
#   'News & Politics': 33,
#   'Nonprofits & Activism': 12},
#  'UCzrzOItQbqY7akga3rPRoMw': {'Entertainment': 0,
#   'Gaming': 91,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 6,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 52,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzrzKRpIYfxWrd7KOiM7Mfw': {'Entertainment': 73,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 14,
#   'Comedy': 133,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 5,
#   'News & Politics': 2,
#   'Nonprofits & Activism': 0},
#  'UCzri8z_k3E5UhVjYkBEoW2g': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 45,
#   'Music': 0,
#   'Science & Technology': 8,
#   'Film & Animation': 3,
#   'Comedy': 0,
#   'Education': 5,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzrhtkj7E-MIAZ2ltngK1vw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 70,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 130,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzralVi6mA-Zq3WGVye9Ycw': {'Entertainment': 306,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 153,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzrVJ3pI6XeIHx1jUQKKNww': {'Entertainment': 56,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 28,
#   'People & Blogs': 29,
#   'Music': 0,
#   'Science & Technology': 4,
#   'Film & Animation': 80,
#   'Comedy': 3,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 1,
#   'Sports': 0,
#   'News & Politics': 78,
#   'Nonprofits & Activism': 0},
#  'UCzrUlkFzxLq8TbWvGJ9uHAQ': {'Entertainment': 5,
#   'Gaming': 0,
#   'Howto & Style': 11,
#   'Travel & Events': 0,
#   'People & Blogs': 34,
#   'Music': 1,
#   'Science & Technology': 3,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 37,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 2,
#   'Sports': 150,
#   'News & Politics': 3,
#   'Nonprofits & Activism': 0},
#  'UCzrTRRYe-m8zyd5FNMLXWAw': {'Entertainment': 2,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 0,
#   'People & Blogs': 114,
#   'Music': 2,
#   'Science & Technology': 7,
#   'Film & Animation': 1,
#   'Comedy': 2,
#   'Education': 434,
#   'Autos & Vehicles': 2,
#   'Pets & Animals': 0,
#   'Sports': 15,
#   'News & Politics': 2,
#   'Nonprofits & Activism': 0},
#  'UCzrRJfoNYDdx9yHkH8ISubQ': {'Entertainment': 38,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 120,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzrL7psSVpReJ53ZUrAWX3w': {'Entertainment': 8,
#   'Gaming': 1,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 1,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 3,
#   'Sports': 32,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzrG8j-dPQTNl7Hf8XAuN6A': {'Entertainment': 1,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 143,
#   'Music': 93,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzr9bpOlVyjxBjKEb30aPNQ': {'Entertainment': 1624,
#   'Gaming': 2263,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 5,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 19,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzr6gD2gZDJL0wdoV43jqog': {'Entertainment': 14,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 13,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 19,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzr-PyKUTPosDadxqMHtoTw': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 23,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 20,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzqwVVF9_Pw1WZrkS0z5P8g': {'Entertainment': 60,
#   'Gaming': 4,
#   'Howto & Style': 50,
#   'Travel & Events': 13,
#   'People & Blogs': 354,
#   'Music': 0,
#   'Science & Technology': 8,
#   'Film & Animation': 1,
#   'Comedy': 53,
#   'Education': 4,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 4,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 1},
#  'UCzqpZ8XdZsLBGNYKbEZn-TA': {'Entertainment': 46,
#   'Gaming': 0,
#   'Howto & Style': 12,
#   'Travel & Events': 432,
#   'People & Blogs': 117,
#   'Music': 2444,
#   'Science & Technology': 1,
#   'Film & Animation': 4,
#   'Comedy': 17,
#   'Education': 9,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 1,
#   'Sports': 1,
#   'News & Politics': 180,
#   'Nonprofits & Activism': 7},
#  'UCzqm-ien6aEj8CSfafHCBzw': {'Entertainment': 2861,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 5186,
#   'Science & Technology': 0,
#   'Film & Animation': 9,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzqh_8hImIc9fhvUu0oVC8w': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 9,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 34,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzqYD2rJzdJqHBGVpu8ETag': {'Entertainment': 151,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 0,
#   'People & Blogs': 2,
#   'Music': 116,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 7,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 2,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 1},
#  'UCzqMAmNP2YG5i6TFjKeAX-A': {'Entertainment': 95,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 2,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 50,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 24,
#   'Nonprofits & Activism': 0},
#  'UCzqLKD4u7A7BPri9GH13Shg': {'Entertainment': 0,
#   'Gaming': 18,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 70,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzqJnkXM5Kj4YGsMywEe9Eg': {'Entertainment': 8,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 3,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 3,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzq2Go7CfANoFnfIps9CK5g': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 91,
#   'Music': 69,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzq0VrH8X3x7r72KDkDgt3g': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 67,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 57,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpxGVyYmCH1_lFjlQLxdYw': {'Entertainment': 22,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 16,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 2,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpgy7wABX-YqjDWrQ2NJRw': {'Entertainment': 326,
#   'Gaming': 23,
#   'Howto & Style': 0,
#   'Travel & Events': 3,
#   'People & Blogs': 27,
#   'Music': 1,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 9,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 360,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpc1yp0a0VdJEB1kO7Cw4Q': {'Entertainment': 94,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 177,
#   'Science & Technology': 0,
#   'Film & Animation': 7,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpbIPE0e6cn7aBzNkgOc9g': {'Entertainment': 190,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 57,
#   'Music': 0,
#   'Science & Technology': 2,
#   'Film & Animation': 12,
#   'Comedy': 0,
#   'Education': 38,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpVHRTF6eD0z48h0TAaq5w': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 107,
#   'Travel & Events': 29,
#   'People & Blogs': 2,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 15,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpUyN2NZSi02f6RSIArTdg': {'Entertainment': 17,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 5,
#   'Music': 35,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 2,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpHPmpnV42DxZeArr2twUg': {'Entertainment': 5,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 13,
#   'Science & Technology': 0,
#   'Film & Animation': 3,
#   'Comedy': 11,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzpGRbJ5MhXnQa7E3pPq42g': {'Entertainment': 2,
#   'Gaming': 0,
#   'Howto & Style': 5,
#   'Travel & Events': 4,
#   'People & Blogs': 5,
#   'Music': 10,
#   'Science & Technology': 47,
#   'Film & Animation': 3,
#   'Comedy': 1,
#   'Education': 17,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 4,
#   'Sports': 0,
#   'News & Politics': 65,
#   'Nonprofits & Activism': 74},
#  'UCzpFUDyb85qA2iikSiiOxjA': {'Entertainment': 0,
#   'Gaming': 1,
#   'Howto & Style': 0,
#   'Travel & Events': 1,
#   'People & Blogs': 116,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 1,
#   'Education': 8,
#   'Autos & Vehicles': 24,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 2,
#   'Nonprofits & Activism': 0},
#  'UCzp8QlVd_hDLfK1LMLDu3dQ': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 361,
#   'Film & Animation': 46,
#   'Comedy': 0,
#   'Education': 38,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 586,
#   'Nonprofits & Activism': 234},
#  'UCzov4EBNNkouOLxknnP1Q3w': {'Entertainment': 291,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 68,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 163,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 2,
#   'Nonprofits & Activism': 0},
#  'UCzouBx4GEEAnm13gpvcL9Rg': {'Entertainment': 0,
#   'Gaming': 35,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 60,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 5},
#  'UCzorFJQFaQILd3zSOf3CoBg': {'Entertainment': 11,
#   'Gaming': 6,
#   'Howto & Style': 177,
#   'Travel & Events': 146,
#   'People & Blogs': 76,
#   'Music': 0,
#   'Science & Technology': 66,
#   'Film & Animation': 14,
#   'Comedy': 5,
#   'Education': 5,
#   'Autos & Vehicles': 52,
#   'Pets & Animals': 275,
#   'Sports': 7,
#   'News & Politics': 32,
#   'Nonprofits & Activism': 1},
#  'UCzokgx8hD52374H3BDQ70SQ': {'Entertainment': 90,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 6,
#   'People & Blogs': 2,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 118,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzoedGkoOFs6ZrllTr-UWUA': {'Entertainment': 373,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 7,
#   'Music': 30,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 132,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzoZaQca_SB0wxK-iSI_16Q': {'Entertainment': 18,
#   'Gaming': 0,
#   'Howto & Style': 66,
#   'Travel & Events': 0,
#   'People & Blogs': 31,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzoVL1aVjec7YKPeG59xKFg': {'Entertainment': 27,
#   'Gaming': 281,
#   'Howto & Style': 0,
#   'Travel & Events': 74,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 2,
#   'Film & Animation': 5,
#   'Comedy': 5,
#   'Education': 1536,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzoS4T5cCSlvhj3KKtjOUNQ': {'Entertainment': 2,
#   'Gaming': 0,
#   'Howto & Style': 68,
#   'Travel & Events': 0,
#   'People & Blogs': 388,
#   'Music': 14,
#   'Science & Technology': 2,
#   'Film & Animation': 0,
#   'Comedy': 12,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 13,
#   'Sports': 33,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 0},
#  'UCzoPv59-YuYk_0cCIHWBBbQ': {'Entertainment': 33,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 2,
#   'Film & Animation': 0,
#   'Comedy': 6,
#   'Education': 30,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzoJd2zxK2Aa257Kv-AXytA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 37,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 13,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzoFjzSkbrDD1GHsz2YNLig': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 169,
# ...
#   'Gaming': 0,
#   'Howto & Style': 127,
#   'Travel & Events': 0,
#   'People & Blogs': 254,
#   'Music': 209,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 63,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 443},
#  'UCzmwJPZkijIfRCAYQkadJ9g': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 8,
#   'Travel & Events': 0,
#   'People & Blogs': 16,
#   'Music': 0,
#   'Science & Technology': 110,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 10},
#  'UCzmse57eZukjyAwddOLA6Qg': {'Entertainment': 145,
#   'Gaming': 1,
#   'Howto & Style': 300,
#   'Travel & Events': 20,
#   'People & Blogs': 22,
#   'Music': 3,
#   'Science & Technology': 0,
#   'Film & Animation': 5,
#   'Comedy': 1,
#   'Education': 2,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 1},
#  'UCzma2ToW1-p5N2EVn5Mf2Bw': {'Entertainment': 66,
#   'Gaming': 0,
#   'Howto & Style': 4,
#   'Travel & Events': 320,
#   'People & Blogs': 1,
#   'Music': 3,
#   'Science & Technology': 0,
#   'Film & Animation': 17,
#   'Comedy': 6,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzmU-b586ACAcIc2guGoLKA': {'Entertainment': 369,
#   'Gaming': 169,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 7,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 3,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzmRLWx1fzaBy0D7kCfOn4w': {'Entertainment': 86,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 115,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzmPOu0RFz-xdVl9QKHrc7g': {'Entertainment': 16,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 5,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzmN6x2tl-OaQPvUwesoh4w': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 5,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 6,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzmHDRW_xdBKdhehd6y8gLA': {'Entertainment': 29,
#   'Gaming': 0,
#   'Howto & Style': 19,
#   'Travel & Events': 1,
#   'People & Blogs': 180,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzmBqpZwmuQquky-6pGuwDA': {'Entertainment': 3,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 44,
#   'Music': 1,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 131,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzm5QwutambV40cDjvlOovA': {'Entertainment': 14,
#   'Gaming': 2,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 10,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 3,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzm1ohiC0R5WbgVcYyXiYvw': {'Entertainment': 29,
#   'Gaming': 0,
#   'Howto & Style': 9,
#   'Travel & Events': 9,
#   'People & Blogs': 0,
#   'Music': 5,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 6,
#   'Education': 9,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 35,
#   'News & Politics': 5,
#   'Nonprofits & Activism': 0},
#  'UCzm1P18seSQmw97m5FmIh8Q': {'Entertainment': 70,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 20,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 5,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlxS0qwetLblfUgYTrnt7Q': {'Entertainment': 18,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 3,
#   'Comedy': 15,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlu25GM2wm3uz-In0rVeGQ': {'Entertainment': 600,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 42,
#   'Music': 1846,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzls5gJTxnJI1uOyXdZm1Gg': {'Entertainment': 20,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 10,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlfx6bYOkfJC0T6YjT5pXg': {'Entertainment': 9,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 1,
#   'People & Blogs': 24,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 2,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 3,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlZYhwwaIGZABqaEffGj-g': {'Entertainment': 131,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 13,
#   'Music': 409,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 13,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlYJ_wt56i98OFlX6vxWFA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 5,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 2,
#   'Education': 0,
#   'Autos & Vehicles': 10,
#   'Pets & Animals': 2,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlV9dVDxDN4eJ6BpKKjsMQ': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 32,
#   'Music': 19,
#   'Science & Technology': 0,
#   'Film & Animation': 15,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlQIrXfh82GnhmfolSer-w': {'Entertainment': 12,
#   'Gaming': 4,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 0,
#   'Education': 1,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 1,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlQ9ES6rzAYVxgBRCwfxlw': {'Entertainment': 96,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 12,
#   'Science & Technology': 0,
#   'Film & Animation': 4,
#   'Comedy': 1,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 397},
#  'UCzlLlSDDqSlZAfxBzbfnXmg': {'Entertainment': 3,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 90,
#   'Music': 0,
#   'Science & Technology': 1,
#   'Film & Animation': 45,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 2,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 2},
#  'UCzlHWDuIsOYutvXdCzvIBLw': {'Entertainment': 136,
#   'Gaming': 0,
#   'Howto & Style': 2,
#   'Travel & Events': 0,
#   'People & Blogs': 742,
#   'Music': 4,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 22,
#   'Education': 0,
#   'Autos & Vehicles': 26,
#   'Pets & Animals': 1,
#   'Sports': 14,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzlGEFvd9_Clle0HY0KoM-Q': {'Entertainment': 10,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 13,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzl7Nkka3BlN1tqnyvwAmSg': {'Entertainment': 9,
#   'Gaming': 54,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 21,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 2,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 3},
#  'UCzklKRfaPGaJWGvRdtYe60Q': {'Entertainment': 95,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 31,
#   'Music': 25,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzkeEAwxes8jkbhJl7srptQ': {'Entertainment': 1,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 15,
#   'Music': 47,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzkYFFKmQL07dc-29Es04Vw': {'Entertainment': 3,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 0,
#   'People & Blogs': 5,
#   'Music': 0,
#   'Science & Technology': 22,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 25,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 1,
#   'Nonprofits & Activism': 0},
#  'UCzkHbTcw-XzH9R8qc7FBXJQ': {'Entertainment': 12,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 6,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzkFu0AVOtXy-vTo028mJxw': {'Entertainment': 29,
#   'Gaming': 1,
#   'Howto & Style': 31,
#   'Travel & Events': 3,
#   'People & Blogs': 85,
#   'Music': 8,
#   'Science & Technology': 3,
#   'Film & Animation': 0,
#   'Comedy': 90,
#   'Education': 5,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 2,
#   'Sports': 0,
#   'News & Politics': 11,
#   'Nonprofits & Activism': 8},
#  'UCzk08fzh5c_BhjQa1w35wtA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 1,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 6,
#   'Comedy': 0,
#   'Education': 8,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 2,
#   'Nonprofits & Activism': 0},
#  'UCzjqt3OxiwxhLduf4kidBRg': {'Entertainment': 105,
#   'Gaming': 12,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 239,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjhPVEfz-z6xJ28_1Squ1g': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 16,
#   'Music': 0,
#   'Science & Technology': 2,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 32,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjeYdI145S8VzGFsODpXoA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 10,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 6,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjYSapwqiQXvVWo03JLtcg': {'Entertainment': 3,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 19,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 1,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 21,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjVzXft4T_iORQtY4El39w': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 1,
#   'Travel & Events': 9,
#   'People & Blogs': 103,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 40,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjSy7WfBx6aAFIH4st8C0w': {'Entertainment': 4,
#   'Gaming': 0,
#   'Howto & Style': 315,
#   'Travel & Events': 41,
#   'People & Blogs': 4,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 108,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjQHubuI2z95VCTESuUl2A': {'Entertainment': 82,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 21,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzjJwaeSBEzBm3qzjNW7sQA': {'Entertainment': 0,
#   'Gaming': 9,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 6,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzj25NxFjI5jJM8StIBOvPA': {'Entertainment': 26,
#   'Gaming': 10,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 4,
#   'Music': 0,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzirj3jHFdxAqOnPxDAxQ_Q': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 87,
#   'Music': 97,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCziq_vt-SLT9Pk4MJmVAaJA': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 59,
#   'Science & Technology': 0,
#   'Film & Animation': 37,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzio43cv-Ib4a-llFGy_pbQ': {'Entertainment': 107,
#   'Gaming': 270,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 0,
#   'Music': 1,
#   'Science & Technology': 0,
#   'Film & Animation': 2,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 6,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0},
#  'UCzikD34vRLAcUlASQnleBnQ': {'Entertainment': 0,
#   'Gaming': 0,
#   'Howto & Style': 0,
#   'Travel & Events': 0,
#   'People & Blogs': 86,
#   'Music': 76,
#   'Science & Technology': 0,
#   'Film & Animation': 0,
#   'Comedy': 0,
#   'Education': 0,
#   'Autos & Vehicles': 0,
#   'Pets & Animals': 0,
#   'Sports': 0,
#   'News & Politics': 0,
#   'Nonprofits & Activism': 0}}

# %%
diversified_ids = dict3.keys()
df_filtre = df[df['channel_id'].isin(diversified_ids)]

# %%
moyennes_vues = df_filtre.groupby(['channel_id', 'categories'])['view_count'].mean().reset_index()
count_videos = df_filtre.groupby(['channel_id', 'categories']).size().reset_index(name='video_count')
max_videos_per_channel = count_videos.groupby('channel_id')['video_count'].max().reset_index()
max_videos_per_channel = max_videos_per_channel.rename(columns={'video_count': 'max_video_count'})
count_videos = count_videos.merge(max_videos_per_channel, on='channel_id')
count_videos['most_category'] = count_videos['video_count'] == count_videos['max_video_count']
moyennes_vues = moyennes_vues.merge(count_videos[['channel_id', 'categories', 'most_category']], on=['channel_id', 'categories'], how='left')

print(moyennes_vues)
# Out:
#                    channel_id            categories     view_count  \
# 0    UCzikD34vRLAcUlASQnleBnQ                 Music   83865.289474
# 1    UCzikD34vRLAcUlASQnleBnQ        People & Blogs   29241.267442
# 2    UCzio43cv-Ib4a-llFGy_pbQ         Entertainment     225.308411
# 3    UCzio43cv-Ib4a-llFGy_pbQ      Film & Animation     930.500000
# 4    UCzio43cv-Ib4a-llFGy_pbQ                Gaming     210.600000
# ..                        ...                   ...            ...
# 904  UCzzzPMh9fZHxc7gxPRB2LHQ        People & Blogs   10573.702128
# 905  UCzzzPMh9fZHxc7gxPRB2LHQ  Science & Technology    4909.000000
# 906  UCzzzZ3-icktxbC3j7hkWqRw         Howto & Style  305485.233333
# 907  UCzzzZ3-icktxbC3j7hkWqRw        People & Blogs  283743.500000
# 908  UCzzzZ3-icktxbC3j7hkWqRw       Travel & Events  112652.333333
#
#      most_category
# 0            False
# 1             True
# 2            False
# 3            False
# 4             True
# ..             ...
# 904          False
# 905          False
# 906           True
# 907          False
# 908          False
#
# [909 rows x 4 columns]

# %%
first_youtubeur = moyennes_vues['channel_id'].iloc[0]  
example_youtubeur = moyennes_vues[moyennes_vues['channel_id'] == first_youtubeur]
print(example_youtubeur)
# Out:
#                  channel_id      categories    view_count  most_category
# 0  UCzikD34vRLAcUlASQnleBnQ           Music  83865.289474          False
# 1  UCzikD34vRLAcUlASQnleBnQ  People & Blogs  29241.267442           True

# %%
max_view_category = moyennes_vues.loc[moyennes_vues.groupby('channel_id')['view_count'].idxmax()]
max_view_category['same_category'] = max_view_category['most_category']
percent_same_category = max_view_category['same_category'].mean() * 100

plt.figure(figsize=(8, 6))
sns.barplot(x=['Same category', 'Other category'], y=[percent_same_category, 100 - percent_same_category])
plt.title("Percentage of channels where the most represented category is also the one with the most views")
plt.ylabel("Percentage")
plt.show()
# Out:
# C:\Users\redou\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# ## Fonction inverse (attention proche de 0 donc renormaliser)

# %%
def compute_distance(cat1, cat2, video_category_distribution_dict):

    for dict in video_category_distribution_dict.values():
        if dict[cat2] == 0:
            return 0
        else:
            return 1-1/dict[cat2]

# %% [markdown]
# # Space representation of the categories

# %% [markdown]
# Knowing the area of each category, wich is the number of occurence of each category and the, area of the intersection of each couple of category, wich is the number of co-occurences we can draw a spacial representation of the categories.

# %%
category_colors = {
    'Film and Animation': '#4C72B0',   # Soft Blue
    'Entertainment': '#DD8452',         # Warm Orange
    'Music': '#55A868',                 # Soft Green
    'Comedy': '#C44E52',                # Deep Red
    'Gaming': '#8172B2',                # Muted Purple
    'Science & Technology': '#8C564B',  # Warm Brown
    'Sports': '#E377C2',                # Vibrant Pink
    'Education': '#7F7F7F',             # Neutral Grey
    'People & Blogs': '#BCBD22',        # Fresh Yellow-green
    'Nonprofits & Activism': '#17BECF', # Cool Light Blue
    'Howto & Style': '#FFB74D',         # Light Orange
    'News & Politics': '#F28E2B',       # Bold Red-Orange
    'Travel & Events': '#C5B0D5',       # Lavender Purple
    'Autos & Vehicles': '#9E7C4D',      # Earthy Tan
    'Pets & Animals': '#F7B6D2'         # Soft Light Pink
}

# %%
from sklearn.manifold import MDS

df_link_strength = pd.DataFrame(get_link_strength_dict(df, dict, categories_list))

# Calculate sizes for each category based on sum of co-occurrences
sizes = df_link_strength.sum(axis=1)

# Apply MDS for 2D representation
mds = MDS(n_components=2, random_state=0, dissimilarity="precomputed")
distance_matrix = 1 / (df_link_strength + 1e-5)
coords = mds.fit_transform(distance_matrix)

# Plot with customized colors and sizes
plt.figure(figsize=(12, 8))

# Plot each category with its associated color and size
for i, category in enumerate(df_link_strength.columns):
    plt.scatter(coords[i, 0], coords[i, 1],
                s=sizes[i] * 10,  # Adjust size scaling here if needed
                color=category_colors.get(category, 'grey'),  # Get color from dict or default to grey
                edgecolor='black',  # Outline color for distinction
                alpha=0.6)  # Adjust transparency for overlap visibility
    plt.text(coords[i, 0], coords[i, 1], category, fontsize=10, ha='center', va='center')

# Titles and labels
plt.title("Spatial Representation of YouTube Categories Based on Co-Occurrence")
plt.xlabel("MDS Dimension 1")
plt.ylabel("MDS Dimension 2")
plt.grid(True)
plt.show()
# Out:
# C:\Users\redou\anaconda3\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# C:\Users\redou\AppData\Local\Temp\ipykernel_712\2700926461.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s=sizes[i] * 10,  # Adjust size scaling here if needed
